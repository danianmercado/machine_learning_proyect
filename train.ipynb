# %%
import os
import json
import string
import collections
import time
from tensorflow.keras.applications.inception_v3 import InceptionV3

def Process_Descriptions(descriptions):
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for key, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            desc = desc.split()
            desc = [word.lower() for word in desc]
            desc = [w.translate(table) for w in desc]
            desc = [word for word in desc if len(word)>1]
            desc = [word for word in desc if word.isalpha()]
            desc_list[i] =  ' '.join(desc)           

def save_descriptions(descriptions, filename):
	lines = list()
	for key, desc_list in descriptions.items():
		for desc in desc_list:
			lines.append(str(key) + ' ' + desc)
	data = '\n'.join(lines)
	file = open(filename, 'w')
	file.write(data)
	file.close()

PATH=os.path.abspath('/Users/danianmercado/Documents/machine_learning')
annotation_t=PATH+'/data/annotations/train.json'
annotation_v=PATH+'/data/annotations/val.json'
with open(annotation_t, 'r') as f:
    annotations_t = json.load(f)
    
with open(annotation_v, 'r') as f:
    annotations_v = json.load(f)
train_img= []
val_img= []
descriptions= collections.OrderedDict()
train_descriptions=collections.OrderedDict()
val_descriptions=collections.OrderedDict()

for annot in annotations_t['annotations']:
    caption = annot['caption']
    image_id = annot['image_id']
    filename = ""
    for img in annotations_t['images']:
        if (img['id'] == image_id):
            filename = img['file_name']
            break
    full_image_path = PATH + '/data/train/'+filename
    image_id_f = filename.split('.')[0]
    if caption != 'Quality issues are too severe to recognize visual content.':
        if image_id_f not in descriptions.keys():
            descriptions[image_id_f] = list()
        if image_id_f not in train_descriptions.keys():
            train_descriptions[image_id_f] = list()
        descriptions[image_id_f].append(caption)
        train_descriptions[image_id_f].append(caption)
        train_img.append(full_image_path)
    
for annot in annotations_v['annotations']:
    caption = annot['caption']
    image_id = annot['image_id']
    filename = ""
    for img in annotations_v['images']:
        if (img['id'] == image_id):
            filename = img['file_name']
            break
    full_image_path = PATH + '/data/val/'+filename
    image_id_f = filename.split('.')[0]
    if image_id_f not in descriptions.keys():
        descriptions[image_id_f] = list()
    if image_id_f not in val_descriptions.keys():
        val_descriptions[image_id_f] = list()
    descriptions[image_id_f].append(caption)
    val_descriptions[image_id_f].append(caption)
    val_img.append(full_image_path)

Process_Descriptions(descriptions)

save_descriptions(descriptions, 'descriptions.txt')

lines = list()
for key in train_descriptions.keys():
    lines.append(key)
data = '\n'.join(lines)
file = open('training_images_names', 'w')
file.write(data)
file.close()

lines = list()
for key in val_descriptions.keys():
    lines.append(key)
data = '\n'.join(lines)
file = open('val_images_names', 'w')
file.write(data)
file.close()

trainImagesPath='/Users/danianmercado/Documents/machine_learning/data/train/'

train_img_set = set(train_img)
val_img_set = set(val_img)

# %%
from os import listdir
from pickle import dump
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model

# extract features from each photo in the directory
def extract_features():
    # load the model
    model = VGG16()
    # re-structure the model
    model.layers.pop()
    model = Model(inputs=model.inputs, outputs=model.layers[-1].output)
    # summarize
    print(model.summary())
    # extract features from each photo
    features = dict()
    f = open('training_images_names', 'r')
    for name in f:
        name = name.strip()
        filename = os.path.abspath('.') + '/data/train/' + name+'.jpg'
        image = load_img(filename, target_size=(224, 224))
        image = img_to_array(image)
        image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
        image = preprocess_input(image)
        feature = model.predict(image, verbose=0)
        image_id = name
        features[image_id] = feature
        print('>%s' % name)
    f.close()
    f = open('val_images_names', 'r')
    for name in f:
        name = name.strip()
        filename = os.path.abspath('.') + '/data/val/' + name + '.jpg'
        image = load_img(filename, target_size=(224, 224))
        image = img_to_array(image)
        image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
        image = preprocess_input(image)
        feature = model.predict(image, verbose=0)
        image_id = name

        features[image_id] = feature
        print('>%s' % name)
    f.close()
    return features

# extract features from all images
features = extract_features()
print('Extracted Features: %d' % len(features))
# save to file
dump(features, open('features.pkl', 'wb'))
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# >VizWiz_train_00000000
# >VizWiz_train_00000001
# >VizWiz_train_00000002
# >VizWiz_train_00000003
# >VizWiz_train_00000004
# >VizWiz_train_00000005
# >VizWiz_train_00000006
# >VizWiz_train_00000007
# >VizWiz_train_00000008
# >VizWiz_train_00000009
# >VizWiz_train_00000010
# >VizWiz_train_00000011
# >VizWiz_train_00000012
# >VizWiz_train_00000013
# >VizWiz_train_00000014
# >VizWiz_train_00000015
# >VizWiz_train_00000016
# >VizWiz_train_00000017
# >VizWiz_train_00000018
# >VizWiz_train_00000020
# >VizWiz_train_00000021
# >VizWiz_train_00000022
# >VizWiz_train_00000023
# >VizWiz_train_00000024
# >VizWiz_train_00000025
# >VizWiz_train_00000026
# >VizWiz_train_00000027
# >VizWiz_train_00000028
# >VizWiz_train_00000029
# >VizWiz_train_00000031
# >VizWiz_train_00000032
# >VizWiz_train_00000033
# >VizWiz_train_00000034
# >VizWiz_train_00000035
# >VizWiz_train_00000036
# >VizWiz_train_00000037
# >VizWiz_train_00000038
# >VizWiz_train_00000039
# >VizWiz_train_00000040
# >VizWiz_train_00000041
# >VizWiz_train_00000042
# >VizWiz_train_00000043
# >VizWiz_train_00000044
# >VizWiz_train_00000045
# >VizWiz_train_00000046
# >VizWiz_train_00000047
# >VizWiz_train_00000048
# >VizWiz_train_00000049
# >VizWiz_train_00000050
# >VizWiz_train_00000051
# >VizWiz_train_00000052
# >VizWiz_train_00000053
# >VizWiz_train_00000054
# >VizWiz_train_00000055
# >VizWiz_train_00000056
# >VizWiz_train_00000057
# >VizWiz_train_00000058
# >VizWiz_train_00000059
# >VizWiz_train_00000060
# >VizWiz_train_00000061
# >VizWiz_train_00000062
# >VizWiz_train_00000063
# >VizWiz_train_00000064
# >VizWiz_train_00000065
# >VizWiz_train_00000066
# >VizWiz_train_00000067
# >VizWiz_train_00000068
# >VizWiz_train_00000069
# >VizWiz_train_00000070
# >VizWiz_train_00000071
# >VizWiz_train_00000072
# >VizWiz_train_00000073
# >VizWiz_train_00000074
# >VizWiz_train_00000075
# >VizWiz_train_00000076
# >VizWiz_train_00000077
# >VizWiz_train_00000078
# >VizWiz_train_00000079
# >VizWiz_train_00000080
# >VizWiz_train_00000081
# >VizWiz_train_00000082
# >VizWiz_train_00000083
# >VizWiz_train_00000084
# >VizWiz_train_00000085
# >VizWiz_train_00000086
# >VizWiz_train_00000087
# >VizWiz_train_00000088
# >VizWiz_train_00000089
# >VizWiz_train_00000090
# >VizWiz_train_00000091
# >VizWiz_train_00000092
# >VizWiz_train_00000093
# >VizWiz_train_00000094
# >VizWiz_train_00000095
# >VizWiz_train_00000096
# >VizWiz_train_00000097
# >VizWiz_train_00000098
# >VizWiz_train_00000099
# >VizWiz_train_00000100
# >VizWiz_train_00000101
# >VizWiz_train_00000102
# >VizWiz_train_00000103
# >VizWiz_train_00000104
# >VizWiz_train_00000105
# >VizWiz_train_00000106
# >VizWiz_train_00000107
# >VizWiz_train_00000108
# >VizWiz_train_00000109
# >VizWiz_train_00000110
# >VizWiz_train_00000111
# >VizWiz_train_00000112
# >VizWiz_train_00000113
# >VizWiz_train_00000114
# >VizWiz_train_00000115
# >VizWiz_train_00000116
# >VizWiz_train_00000117
# >VizWiz_train_00000118
# >VizWiz_train_00000119
# >VizWiz_train_00000120
# >VizWiz_train_00000121
# >VizWiz_train_00000122
# >VizWiz_train_00000123
# >VizWiz_train_00000124
# >VizWiz_train_00000125
# >VizWiz_train_00000126
# >VizWiz_train_00000127
# >VizWiz_train_00000128
# >VizWiz_train_00000129
# >VizWiz_train_00000130
# >VizWiz_train_00000131
# >VizWiz_train_00000132
# >VizWiz_train_00000133
# >VizWiz_train_00000134
# >VizWiz_train_00000135
# >VizWiz_train_00000136
# >VizWiz_train_00000137
# >VizWiz_train_00000138
# >VizWiz_train_00000139
# >VizWiz_train_00000140
# >VizWiz_train_00000141
# >VizWiz_train_00000142
# >VizWiz_train_00000143
# >VizWiz_train_00000144
# >VizWiz_train_00000145
# >VizWiz_train_00000146
# >VizWiz_train_00000147
# >VizWiz_train_00000148
# >VizWiz_train_00000149
# >VizWiz_train_00000150
# >VizWiz_train_00000151
# >VizWiz_train_00000152
# >VizWiz_train_00000153
# >VizWiz_train_00000154
# >VizWiz_train_00000156
# >VizWiz_train_00000157
# >VizWiz_train_00000158
# >VizWiz_train_00000159
# >VizWiz_train_00000160
# >VizWiz_train_00000161
# >VizWiz_train_00000162
# >VizWiz_train_00000163
# >VizWiz_train_00000164
# >VizWiz_train_00000165
# >VizWiz_train_00000166
# >VizWiz_train_00000167
# >VizWiz_train_00000168
# >VizWiz_train_00000169
# >VizWiz_train_00000170
# >VizWiz_train_00000171
# >VizWiz_train_00000172
# >VizWiz_train_00000173
# >VizWiz_train_00000174
# >VizWiz_train_00000175
# >VizWiz_train_00000176
# >VizWiz_train_00000177
# >VizWiz_train_00000178
# >VizWiz_train_00000179
# >VizWiz_train_00000180
# >VizWiz_train_00000181
# >VizWiz_train_00000182
# >VizWiz_train_00000183
# >VizWiz_train_00000184
# >VizWiz_train_00000185
# >VizWiz_train_00000186
# >VizWiz_train_00000187
# >VizWiz_train_00000188
# >VizWiz_train_00000189
# >VizWiz_train_00000190
# >VizWiz_train_00000191
# >VizWiz_train_00000192
# >VizWiz_train_00000193
# >VizWiz_train_00000194
# >VizWiz_train_00000195
# >VizWiz_train_00000196
# >VizWiz_train_00000197
# >VizWiz_train_00000198
# >VizWiz_train_00000199
# >VizWiz_train_00000200
# >VizWiz_train_00000201
# >VizWiz_train_00000202
# >VizWiz_train_00000203
# >VizWiz_train_00000204
# >VizWiz_train_00000205
# >VizWiz_train_00000206
# >VizWiz_train_00000207
# >VizWiz_train_00000208
# >VizWiz_train_00000209
# >VizWiz_train_00000210
# >VizWiz_train_00000211
# >VizWiz_train_00000212
# >VizWiz_train_00000213
# >VizWiz_train_00000214
# >VizWiz_train_00000215
# >VizWiz_train_00000216
# >VizWiz_train_00000217
# >VizWiz_train_00000218
# >VizWiz_train_00000219
# >VizWiz_train_00000220
# >VizWiz_train_00000221
# >VizWiz_train_00000222
# >VizWiz_train_00000223
# >VizWiz_train_00000224
# >VizWiz_train_00000225
# >VizWiz_train_00000226
# >VizWiz_train_00000227
# >VizWiz_train_00000228
# >VizWiz_train_00000229
# >VizWiz_train_00000230
# >VizWiz_train_00000231
# >VizWiz_train_00000232
# >VizWiz_train_00000233
# >VizWiz_train_00000234
# >VizWiz_train_00000235
# >VizWiz_train_00000236
# >VizWiz_train_00000237
# >VizWiz_train_00000238
# >VizWiz_train_00000239
# >VizWiz_train_00000240
# >VizWiz_train_00000241
# >VizWiz_train_00000242
# >VizWiz_train_00000243
# >VizWiz_train_00000244
# >VizWiz_train_00000245
# >VizWiz_train_00000246
# >VizWiz_train_00000247
# >VizWiz_train_00000248
# >VizWiz_train_00000249
# >VizWiz_train_00000250
# >VizWiz_train_00000251
# >VizWiz_train_00000252
# >VizWiz_train_00000253
# >VizWiz_train_00000254
# >VizWiz_train_00000255
# >VizWiz_train_00000256
# >VizWiz_train_00000257
# >VizWiz_train_00000258
# >VizWiz_train_00000259
# >VizWiz_train_00000260
# >VizWiz_train_00000261
# >VizWiz_train_00000263
# >VizWiz_train_00000264
# >VizWiz_train_00000265
# >VizWiz_train_00000266
# >VizWiz_train_00000267
# >VizWiz_train_00000268
# >VizWiz_train_00000269
# >VizWiz_train_00000270
# >VizWiz_train_00000271
# >VizWiz_train_00000272
# >VizWiz_train_00000274
# >VizWiz_train_00000275
# >VizWiz_train_00000276
# >VizWiz_train_00000277
# >VizWiz_train_00000278
# >VizWiz_train_00000279
# >VizWiz_train_00000280
# >VizWiz_train_00000281
# >VizWiz_train_00000282
# >VizWiz_train_00000283
# >VizWiz_train_00000284
# >VizWiz_train_00000285
# >VizWiz_train_00000286
# >VizWiz_train_00000287
# >VizWiz_train_00000288
# >VizWiz_train_00000289
# >VizWiz_train_00000290
# >VizWiz_train_00000291
# >VizWiz_train_00000293
# >VizWiz_train_00000294
# >VizWiz_train_00000295
# >VizWiz_train_00000296
# >VizWiz_train_00000297
# >VizWiz_train_00000298
# >VizWiz_train_00000299
# >VizWiz_train_00000300
# >VizWiz_train_00000301
# >VizWiz_train_00000302
# >VizWiz_train_00000303
# >VizWiz_train_00000304
# >VizWiz_train_00000305
# >VizWiz_train_00000306
# >VizWiz_train_00000307
# >VizWiz_train_00000309
# >VizWiz_train_00000310
# >VizWiz_train_00000311
# >VizWiz_train_00000312
# >VizWiz_train_00000313
# >VizWiz_train_00000314
# >VizWiz_train_00000315
# >VizWiz_train_00000316
# >VizWiz_train_00000317
# >VizWiz_train_00000318
# >VizWiz_train_00000319
# >VizWiz_train_00000320
# >VizWiz_train_00000321
# >VizWiz_train_00000322
# >VizWiz_train_00000323
# >VizWiz_train_00000324
# >VizWiz_train_00000325
# >VizWiz_train_00000326
# >VizWiz_train_00000327
# >VizWiz_train_00000328
# >VizWiz_train_00000329
# >VizWiz_train_00000330
# >VizWiz_train_00000331
# >VizWiz_train_00000332
# >VizWiz_train_00000333
# >VizWiz_train_00000334
# >VizWiz_train_00000335
# >VizWiz_train_00000336
# >VizWiz_train_00000337
# >VizWiz_train_00000338
# >VizWiz_train_00000339
# >VizWiz_train_00000340
# >VizWiz_train_00000341
# >VizWiz_train_00000342
# >VizWiz_train_00000343
# >VizWiz_train_00000344
# >VizWiz_train_00000345
# >VizWiz_train_00000346
# >VizWiz_train_00000348
# >VizWiz_train_00000349
# >VizWiz_train_00000350
# >VizWiz_train_00000351
# >VizWiz_train_00000352
# >VizWiz_train_00000353
# >VizWiz_train_00000354
# >VizWiz_train_00000355
# >VizWiz_train_00000356
# >VizWiz_train_00000357
# >VizWiz_train_00000358
# >VizWiz_train_00000359
# >VizWiz_train_00000360
# >VizWiz_train_00000361
# >VizWiz_train_00000362
# >VizWiz_train_00000363
# >VizWiz_train_00000364
# >VizWiz_train_00000365
# >VizWiz_train_00000366
# >VizWiz_train_00000367
# >VizWiz_train_00000368
# >VizWiz_train_00000369
# >VizWiz_train_00000370
# >VizWiz_train_00000371
# >VizWiz_train_00000372
# >VizWiz_train_00000373
# >VizWiz_train_00000374
# >VizWiz_train_00000375
# >VizWiz_train_00000376
# >VizWiz_train_00000377
# >VizWiz_train_00000378
# >VizWiz_train_00000379
# >VizWiz_train_00000380
# >VizWiz_train_00000381
# >VizWiz_train_00000382
# >VizWiz_train_00000383
# >VizWiz_train_00000384
# >VizWiz_train_00000385
# >VizWiz_train_00000386
# >VizWiz_train_00000387
# >VizWiz_train_00000388
# >VizWiz_train_00000389
# >VizWiz_train_00000390
# >VizWiz_train_00000391
# >VizWiz_train_00000392
# >VizWiz_train_00000393
# >VizWiz_train_00000394
# >VizWiz_train_00000395
# >VizWiz_train_00000396
# >VizWiz_train_00000397
# >VizWiz_train_00000398
# >VizWiz_train_00000399
# >VizWiz_train_00000400
# >VizWiz_train_00000401
# >VizWiz_train_00000402
# >VizWiz_train_00000403
# >VizWiz_train_00000404
# >VizWiz_train_00000405
# >VizWiz_train_00000406
# >VizWiz_train_00000407
# >VizWiz_train_00000408
# >VizWiz_train_00000409
# >VizWiz_train_00000410
# >VizWiz_train_00000411
# >VizWiz_train_00000412
# >VizWiz_train_00000413
# >VizWiz_train_00000414
# >VizWiz_train_00000415
# >VizWiz_train_00000416
# >VizWiz_train_00000417
# >VizWiz_train_00000418
# >VizWiz_train_00000419
# >VizWiz_train_00000420
# >VizWiz_train_00000421
# >VizWiz_train_00000422
# >VizWiz_train_00000423
# >VizWiz_train_00000424
# >VizWiz_train_00000425
# >VizWiz_train_00000426
# >VizWiz_train_00000427
# >VizWiz_train_00000428
# >VizWiz_train_00000429
# >VizWiz_train_00000430
# >VizWiz_train_00000431
# >VizWiz_train_00000432
# >VizWiz_train_00000433
# >VizWiz_train_00000434
# >VizWiz_train_00000435
# >VizWiz_train_00000436
# >VizWiz_train_00000437
# >VizWiz_train_00000438
# >VizWiz_train_00000439
# >VizWiz_train_00000440
# >VizWiz_train_00000441
# >VizWiz_train_00000442
# >VizWiz_train_00000443
# >VizWiz_train_00000444
# >VizWiz_train_00000445
# >VizWiz_train_00000446
# >VizWiz_train_00000447
# >VizWiz_train_00000448
# >VizWiz_train_00000449
# >VizWiz_train_00000450
# >VizWiz_train_00000451
# >VizWiz_train_00000452
# >VizWiz_train_00000453
# >VizWiz_train_00000454
# >VizWiz_train_00000455
# >VizWiz_train_00000456
# >VizWiz_train_00000457
# >VizWiz_train_00000458
# >VizWiz_train_00000459
# >VizWiz_train_00000460
# >VizWiz_train_00000461
# >VizWiz_train_00000462
# >VizWiz_train_00000463
# >VizWiz_train_00000464
# >VizWiz_train_00000465
# >VizWiz_train_00000466
# >VizWiz_train_00000467
# >VizWiz_train_00000468
# >VizWiz_train_00000469
# >VizWiz_train_00000470
# >VizWiz_train_00000471
# >VizWiz_train_00000472
# >VizWiz_train_00000473
# >VizWiz_train_00000474
# >VizWiz_train_00000475
# >VizWiz_train_00000476
# >VizWiz_train_00000477
# >VizWiz_train_00000478
# >VizWiz_train_00000479
# >VizWiz_train_00000480
# >VizWiz_train_00000482
# >VizWiz_train_00000483
# >VizWiz_train_00000484
# >VizWiz_train_00000485
# >VizWiz_train_00000486
# >VizWiz_train_00000487
# >VizWiz_train_00000488
# >VizWiz_train_00000489
# >VizWiz_train_00000490
# >VizWiz_train_00000491
# >VizWiz_train_00000492
# >VizWiz_train_00000493
# >VizWiz_train_00000494
# >VizWiz_train_00000495
# >VizWiz_train_00000496
# >VizWiz_train_00000497
# >VizWiz_train_00000498
# >VizWiz_train_00000499
# >VizWiz_train_00000500
# >VizWiz_train_00000501
# >VizWiz_train_00000502
# >VizWiz_train_00000503
# >VizWiz_train_00000504
# >VizWiz_train_00000505
# >VizWiz_train_00000506
# >VizWiz_train_00000507
# >VizWiz_train_00000508
# >VizWiz_train_00000509
# >VizWiz_train_00000510
# >VizWiz_train_00000511
# >VizWiz_train_00000512
# >VizWiz_train_00000513
# >VizWiz_train_00000514
# >VizWiz_train_00000515
# >VizWiz_train_00000516
# >VizWiz_train_00000517
# >VizWiz_train_00000518
# >VizWiz_train_00000519
# >VizWiz_train_00000520
# >VizWiz_train_00000521
# >VizWiz_train_00000522
# >VizWiz_train_00000523
# >VizWiz_train_00000524
# >VizWiz_train_00000525
# >VizWiz_train_00000526
# >VizWiz_train_00000527
# >VizWiz_train_00000528
# >VizWiz_train_00000529
# >VizWiz_train_00000530
# >VizWiz_train_00000531
# >VizWiz_train_00000532
# >VizWiz_train_00000533
# >VizWiz_train_00000534
# >VizWiz_train_00000535
# >VizWiz_train_00000536
# >VizWiz_train_00000537
# >VizWiz_train_00000538
# >VizWiz_train_00000539
# >VizWiz_train_00000540
# >VizWiz_train_00000541
# >VizWiz_train_00000542
# >VizWiz_train_00000543
# >VizWiz_train_00000544
# >VizWiz_train_00000545
# >VizWiz_train_00000546
# >VizWiz_train_00000547
# >VizWiz_train_00000548
# >VizWiz_train_00000549
# >VizWiz_train_00000550
# >VizWiz_train_00000551
# >VizWiz_train_00000552
# >VizWiz_train_00000553
# >VizWiz_train_00000554
# >VizWiz_train_00000555
# >VizWiz_train_00000556
# >VizWiz_train_00000557
# >VizWiz_train_00000558
# >VizWiz_train_00000559
# >VizWiz_train_00000560
# >VizWiz_train_00000561
# >VizWiz_train_00000562
# >VizWiz_train_00000563
# >VizWiz_train_00000564
# >VizWiz_train_00000565
# >VizWiz_train_00000566
# >VizWiz_train_00000567
# >VizWiz_train_00000568
# >VizWiz_train_00000569
# >VizWiz_train_00000570
# >VizWiz_train_00000571
# >VizWiz_train_00000572
# >VizWiz_train_00000573
# >VizWiz_train_00000574
# >VizWiz_train_00000575
# >VizWiz_train_00000576
# >VizWiz_train_00000577
# >VizWiz_train_00000578
# >VizWiz_train_00000579
# >VizWiz_train_00000580
# >VizWiz_train_00000581
# >VizWiz_train_00000582
# >VizWiz_train_00000583
# >VizWiz_train_00000584
# >VizWiz_train_00000585
# >VizWiz_train_00000586
# >VizWiz_train_00000587
# >VizWiz_train_00000588
# >VizWiz_train_00000589
# >VizWiz_train_00000590
# >VizWiz_train_00000591
# >VizWiz_train_00000592
# >VizWiz_train_00000593
# >VizWiz_train_00000595
# >VizWiz_train_00000596
# >VizWiz_train_00000597
# >VizWiz_train_00000598
# >VizWiz_train_00000599
# >VizWiz_train_00000600
# >VizWiz_train_00000601
# >VizWiz_train_00000602
# >VizWiz_train_00000603
# >VizWiz_train_00000604
# >VizWiz_train_00000607
# >VizWiz_train_00000608
# >VizWiz_train_00000609
# >VizWiz_train_00000610
# >VizWiz_train_00000611
# >VizWiz_train_00000612
# >VizWiz_train_00000613
# >VizWiz_train_00000614
# >VizWiz_train_00000615
# >VizWiz_train_00000616
# >VizWiz_train_00000617
# >VizWiz_train_00000618
# >VizWiz_train_00000619
# >VizWiz_train_00000620
# >VizWiz_train_00000621
# >VizWiz_train_00000622
# >VizWiz_train_00000623
# >VizWiz_train_00000624
# >VizWiz_train_00000625
# >VizWiz_train_00000626
# >VizWiz_train_00000627
# >VizWiz_train_00000628
# >VizWiz_train_00000629
# >VizWiz_train_00000630
# >VizWiz_train_00000631
# >VizWiz_train_00000632
# >VizWiz_train_00000633
# >VizWiz_train_00000634
# >VizWiz_train_00000635
# >VizWiz_train_00000636
# >VizWiz_train_00000637
# >VizWiz_train_00000638
# >VizWiz_train_00000639
# >VizWiz_train_00000640
# >VizWiz_train_00000641
# >VizWiz_train_00000642
# >VizWiz_train_00000643
# >VizWiz_train_00000644
# >VizWiz_train_00000645
# >VizWiz_train_00000646
# >VizWiz_train_00000647
# >VizWiz_train_00000648
# >VizWiz_train_00000649
# >VizWiz_train_00000650
# >VizWiz_train_00000651
# >VizWiz_train_00000652
# >VizWiz_train_00000653
# >VizWiz_train_00000654
# >VizWiz_train_00000655
# >VizWiz_train_00000656
# >VizWiz_train_00000657
# >VizWiz_train_00000658
# >VizWiz_train_00000659
# >VizWiz_train_00000660
# >VizWiz_train_00000661
# >VizWiz_train_00000662
# >VizWiz_train_00000663
# >VizWiz_train_00000664
# >VizWiz_train_00000665
# >VizWiz_train_00000666
# >VizWiz_train_00000667
# >VizWiz_train_00000668
# >VizWiz_train_00000669
# >VizWiz_train_00000670
# >VizWiz_train_00000671
# >VizWiz_train_00000672
# >VizWiz_train_00000673
# >VizWiz_train_00000674
# >VizWiz_train_00000675
# >VizWiz_train_00000676
# >VizWiz_train_00000678
# >VizWiz_train_00000679
# >VizWiz_train_00000680
# >VizWiz_train_00000681
# >VizWiz_train_00000682
# >VizWiz_train_00000683
# >VizWiz_train_00000684
# >VizWiz_train_00000685
# >VizWiz_train_00000686
# >VizWiz_train_00000687
# >VizWiz_train_00000688
# >VizWiz_train_00000689
# >VizWiz_train_00000690
# >VizWiz_train_00000691
# >VizWiz_train_00000692
# >VizWiz_train_00000693
# >VizWiz_train_00000694
# >VizWiz_train_00000695
# >VizWiz_train_00000696
# >VizWiz_train_00000697
# >VizWiz_train_00000698
# >VizWiz_train_00000699
# >VizWiz_train_00000700
# >VizWiz_train_00000701
# >VizWiz_train_00000702
# >VizWiz_train_00000703
# >VizWiz_train_00000704
# >VizWiz_train_00000705
# >VizWiz_train_00000706
# >VizWiz_train_00000707
# >VizWiz_train_00000708
# >VizWiz_train_00000709
# >VizWiz_train_00000710
# >VizWiz_train_00000711
# >VizWiz_train_00000712
# >VizWiz_train_00000713
# >VizWiz_train_00000714
# >VizWiz_train_00000715
# >VizWiz_train_00000716
# >VizWiz_train_00000717
# >VizWiz_train_00000718
# >VizWiz_train_00000719
# >VizWiz_train_00000720
# >VizWiz_train_00000721
# >VizWiz_train_00000722
# >VizWiz_train_00000723
# >VizWiz_train_00000724
# >VizWiz_train_00000725
# >VizWiz_train_00000726
# >VizWiz_train_00000727
# >VizWiz_train_00000728
# >VizWiz_train_00000729
# >VizWiz_train_00000730
# >VizWiz_train_00000731
# >VizWiz_train_00000732
# >VizWiz_train_00000733
# >VizWiz_train_00000734
# >VizWiz_train_00000735
# >VizWiz_train_00000736
# >VizWiz_train_00000737
# >VizWiz_train_00000738
# >VizWiz_train_00000739
# >VizWiz_train_00000740
# >VizWiz_train_00000741
# >VizWiz_train_00000742
# >VizWiz_train_00000743
# >VizWiz_train_00000744
# >VizWiz_train_00000745
# >VizWiz_train_00000746
# >VizWiz_train_00000747
# >VizWiz_train_00000748
# >VizWiz_train_00000749
# >VizWiz_train_00000750
# >VizWiz_train_00000751
# >VizWiz_train_00000752
# >VizWiz_train_00000753
# >VizWiz_train_00000754
# >VizWiz_train_00000755
# >VizWiz_train_00000756
# >VizWiz_train_00000757
# >VizWiz_train_00000758
# >VizWiz_train_00000759
# >VizWiz_train_00000760
# >VizWiz_train_00000761
# >VizWiz_train_00000762
# >VizWiz_train_00000763
# >VizWiz_train_00000764
# >VizWiz_train_00000765
# >VizWiz_train_00000766
# >VizWiz_train_00000767
# >VizWiz_train_00000768
# >VizWiz_train_00000769
# >VizWiz_train_00000770
# >VizWiz_train_00000771
# >VizWiz_train_00000772
# >VizWiz_train_00000773
# >VizWiz_train_00000774
# >VizWiz_train_00000775
# >VizWiz_train_00000776
# >VizWiz_train_00000777
# >VizWiz_train_00000778
# >VizWiz_train_00000779
# >VizWiz_train_00000780
# >VizWiz_train_00000781
# >VizWiz_train_00000782
# >VizWiz_train_00000783
# >VizWiz_train_00000784
# >VizWiz_train_00000785
# >VizWiz_train_00000786
# >VizWiz_train_00000787
# >VizWiz_train_00000788
# >VizWiz_train_00000789
# >VizWiz_train_00000790
# >VizWiz_train_00000791
# >VizWiz_train_00000793
# >VizWiz_train_00000794
# >VizWiz_train_00000795
# >VizWiz_train_00000796
# >VizWiz_train_00000797
# >VizWiz_train_00000798
# >VizWiz_train_00000799
# >VizWiz_train_00000800
# >VizWiz_train_00000801
# >VizWiz_train_00000802
# >VizWiz_train_00000803
# >VizWiz_train_00000804
# >VizWiz_train_00000805
# >VizWiz_train_00000806
# >VizWiz_train_00000807
# >VizWiz_train_00000808
# >VizWiz_train_00000809
# >VizWiz_train_00000810
# >VizWiz_train_00000811
# >VizWiz_train_00000812
# >VizWiz_train_00000813
# >VizWiz_train_00000814
# >VizWiz_train_00000815
# >VizWiz_train_00000816
# >VizWiz_train_00000817
# >VizWiz_train_00000818
# >VizWiz_train_00000820
# >VizWiz_train_00000821
# >VizWiz_train_00000822
# >VizWiz_train_00000823
# >VizWiz_train_00000824
# >VizWiz_train_00000825
# >VizWiz_train_00000826
# >VizWiz_train_00000827
# >VizWiz_train_00000828
# >VizWiz_train_00000829
# >VizWiz_train_00000830
# >VizWiz_train_00000831
# >VizWiz_train_00000832
# >VizWiz_train_00000833
# >VizWiz_train_00000834
# >VizWiz_train_00000835
# >VizWiz_train_00000836
# >VizWiz_train_00000837
# >VizWiz_train_00000838
# >VizWiz_train_00000839
# >VizWiz_train_00000840
# >VizWiz_train_00000841
# >VizWiz_train_00000842
# >VizWiz_train_00000843
# >VizWiz_train_00000844
# >VizWiz_train_00000845
# >VizWiz_train_00000846
# >VizWiz_train_00000847
# >VizWiz_train_00000848
# >VizWiz_train_00000849
# >VizWiz_train_00000850
# >VizWiz_train_00000851
# >VizWiz_train_00000852
# >VizWiz_train_00000853
# >VizWiz_train_00000854
# >VizWiz_train_00000855
# >VizWiz_train_00000856
# >VizWiz_train_00000857
# >VizWiz_train_00000858
# >VizWiz_train_00000859
# >VizWiz_train_00000860
# >VizWiz_train_00000861
# >VizWiz_train_00000862
# >VizWiz_train_00000863
# >VizWiz_train_00000864
# >VizWiz_train_00000865
# >VizWiz_train_00000866
# >VizWiz_train_00000867
# >VizWiz_train_00000868
# >VizWiz_train_00000869
# >VizWiz_train_00000870
# >VizWiz_train_00000871
# >VizWiz_train_00000872
# >VizWiz_train_00000873
# >VizWiz_train_00000874
# >VizWiz_train_00000875
# >VizWiz_train_00000876
# >VizWiz_train_00000877
# >VizWiz_train_00000878
# >VizWiz_train_00000879
# >VizWiz_train_00000880
# >VizWiz_train_00000881
# >VizWiz_train_00000882
# >VizWiz_train_00000883
# >VizWiz_train_00000884
# >VizWiz_train_00000885
# >VizWiz_train_00000886
# >VizWiz_train_00000887
# >VizWiz_train_00000888
# >VizWiz_train_00000889
# >VizWiz_train_00000890
# >VizWiz_train_00000891
# >VizWiz_train_00000892
# >VizWiz_train_00000893
# >VizWiz_train_00000894
# >VizWiz_train_00000895
# >VizWiz_train_00000896
# >VizWiz_train_00000897
# >VizWiz_train_00000898
# >VizWiz_train_00000899
# >VizWiz_train_00000900
# >VizWiz_train_00000901
# >VizWiz_train_00000902
# >VizWiz_train_00000903
# >VizWiz_train_00000904
# >VizWiz_train_00000905
# >VizWiz_train_00000906
# >VizWiz_train_00000907
# >VizWiz_train_00000908
# >VizWiz_train_00000909
# >VizWiz_train_00000910
# >VizWiz_train_00000911
# >VizWiz_train_00000912
# >VizWiz_train_00000913
# >VizWiz_train_00000914
# >VizWiz_train_00000915
# >VizWiz_train_00000916
# >VizWiz_train_00000917
# >VizWiz_train_00000918
# >VizWiz_train_00000919
# >VizWiz_train_00000920
# >VizWiz_train_00000921
# >VizWiz_train_00000922
# >VizWiz_train_00000923
# >VizWiz_train_00000924
# >VizWiz_train_00000925
# >VizWiz_train_00000926
# >VizWiz_train_00000927
# >VizWiz_train_00000928
# >VizWiz_train_00000929
# >VizWiz_train_00000930
# >VizWiz_train_00000931
# >VizWiz_train_00000932
# >VizWiz_train_00000933
# >VizWiz_train_00000934
# >VizWiz_train_00000935
# >VizWiz_train_00000936
# >VizWiz_train_00000937
# >VizWiz_train_00000938
# >VizWiz_train_00000939
# >VizWiz_train_00000940
# >VizWiz_train_00000941
# >VizWiz_train_00000942
# >VizWiz_train_00000943
# >VizWiz_train_00000944
# >VizWiz_train_00000945
# >VizWiz_train_00000946
# >VizWiz_train_00000947
# >VizWiz_train_00000948
# >VizWiz_train_00000949
# >VizWiz_train_00000950
# >VizWiz_train_00000951
# >VizWiz_train_00000952
# >VizWiz_train_00000953
# >VizWiz_train_00000954
# >VizWiz_train_00000955
# >VizWiz_train_00000956
# >VizWiz_train_00000957
# >VizWiz_train_00000958
# >VizWiz_train_00000959
# >VizWiz_train_00000960
# >VizWiz_train_00000961
# >VizWiz_train_00000962
# >VizWiz_train_00000963
# >VizWiz_train_00000964
# >VizWiz_train_00000965
# >VizWiz_train_00000966
# >VizWiz_train_00000967
# >VizWiz_train_00000968
# >VizWiz_train_00000969
# >VizWiz_train_00000970
# >VizWiz_train_00000971
# >VizWiz_train_00000972
# >VizWiz_train_00000973
# >VizWiz_train_00000974
# >VizWiz_train_00000975
# >VizWiz_train_00000976
# >VizWiz_train_00000977
# >VizWiz_train_00000978
# >VizWiz_train_00000979
# >VizWiz_train_00000980
# >VizWiz_train_00000981
# >VizWiz_train_00000982
# >VizWiz_train_00000983
# >VizWiz_train_00000984
# >VizWiz_train_00000985
# >VizWiz_train_00000986
# >VizWiz_train_00000987
# >VizWiz_train_00000988
# >VizWiz_train_00000989
# >VizWiz_train_00000990
# >VizWiz_train_00000991
# >VizWiz_train_00000992
# >VizWiz_train_00000993
# >VizWiz_train_00000994
# >VizWiz_train_00000995
# >VizWiz_train_00000996
# >VizWiz_train_00000997
# >VizWiz_train_00000998
# >VizWiz_train_00000999
# >VizWiz_train_00001000
# >VizWiz_train_00001001
# >VizWiz_train_00001002
# >VizWiz_train_00001003
# >VizWiz_train_00001004
# >VizWiz_train_00001005
# >VizWiz_train_00001006
# >VizWiz_train_00001007
# >VizWiz_train_00001008
# >VizWiz_train_00001009
# >VizWiz_train_00001010
# >VizWiz_train_00001011
# >VizWiz_train_00001012
# >VizWiz_train_00001013
# >VizWiz_train_00001014
# >VizWiz_train_00001015
# >VizWiz_train_00001016
# >VizWiz_train_00001017
# >VizWiz_train_00001018
# >VizWiz_train_00001019
# >VizWiz_train_00001020
# >VizWiz_train_00001021
# >VizWiz_train_00001022
# >VizWiz_train_00001023
# >VizWiz_train_00001024
# >VizWiz_train_00001025
# >VizWiz_train_00001026
# >VizWiz_train_00001027
# >VizWiz_train_00001028
# >VizWiz_train_00001029
# >VizWiz_train_00001030
# >VizWiz_train_00001031
# >VizWiz_train_00001033
# >VizWiz_train_00001034
# >VizWiz_train_00001035
# >VizWiz_train_00001036
# >VizWiz_train_00001038
# >VizWiz_train_00001039
# >VizWiz_train_00001040
# >VizWiz_train_00001041
# >VizWiz_train_00001042
# >VizWiz_train_00001043
# >VizWiz_train_00001044
# >VizWiz_train_00001045
# >VizWiz_train_00001046
# >VizWiz_train_00001047
# >VizWiz_train_00001048
# >VizWiz_train_00001049
# >VizWiz_train_00001050
# >VizWiz_train_00001051
# >VizWiz_train_00001052
# >VizWiz_train_00001053
# >VizWiz_train_00001054
# >VizWiz_train_00001055
# >VizWiz_train_00001056
# >VizWiz_train_00001057
# >VizWiz_train_00001058
# >VizWiz_train_00001059
# >VizWiz_train_00001060
# >VizWiz_train_00001061
# >VizWiz_train_00001062
# >VizWiz_train_00001063
# >VizWiz_train_00001064
# >VizWiz_train_00001065
# >VizWiz_train_00001066
# >VizWiz_train_00001067
# >VizWiz_train_00001068
# >VizWiz_train_00001069
# >VizWiz_train_00001070
# >VizWiz_train_00001071
# >VizWiz_train_00001072
# >VizWiz_train_00001073
# >VizWiz_train_00001074
# >VizWiz_train_00001075
# >VizWiz_train_00001076
# >VizWiz_train_00001077
# >VizWiz_train_00001078
# >VizWiz_train_00001079
# >VizWiz_train_00001080
# >VizWiz_train_00001081
# >VizWiz_train_00001082
# >VizWiz_train_00001083
# >VizWiz_train_00001084
# >VizWiz_train_00001085
# >VizWiz_train_00001086
# >VizWiz_train_00001087
# >VizWiz_train_00001088
# >VizWiz_train_00001089
# >VizWiz_train_00001090
# >VizWiz_train_00001091
# >VizWiz_train_00001092
# >VizWiz_train_00001093
# >VizWiz_train_00001094
# >VizWiz_train_00001095
# >VizWiz_train_00001096
# >VizWiz_train_00001097
# >VizWiz_train_00001098
# >VizWiz_train_00001099
# >VizWiz_train_00001100
# >VizWiz_train_00001101
# >VizWiz_train_00001102
# >VizWiz_train_00001103
# >VizWiz_train_00001104
# >VizWiz_train_00001105
# >VizWiz_train_00001106
# >VizWiz_train_00001107
# >VizWiz_train_00001108
# >VizWiz_train_00001109
# >VizWiz_train_00001110
# >VizWiz_train_00001111
# >VizWiz_train_00001112
# >VizWiz_train_00001113
# >VizWiz_train_00001114
# >VizWiz_train_00001115
# >VizWiz_train_00001116
# >VizWiz_train_00001117
# >VizWiz_train_00001118
# >VizWiz_train_00001119
# >VizWiz_train_00001120
# >VizWiz_train_00001121
# >VizWiz_train_00001122
# >VizWiz_train_00001123
# >VizWiz_train_00001124
# >VizWiz_train_00001125
# >VizWiz_train_00001126
# >VizWiz_train_00001127
# >VizWiz_train_00001128
# >VizWiz_train_00001129
# >VizWiz_train_00001130
# >VizWiz_train_00001131
# >VizWiz_train_00001132
# >VizWiz_train_00001133
# >VizWiz_train_00001134
# >VizWiz_train_00001135
# >VizWiz_train_00001136
# >VizWiz_train_00001137
# >VizWiz_train_00001138
# >VizWiz_train_00001139
# >VizWiz_train_00001140
# >VizWiz_train_00001141
# >VizWiz_train_00001142
# >VizWiz_train_00001143
# >VizWiz_train_00001144
# >VizWiz_train_00001145
# >VizWiz_train_00001146
# >VizWiz_train_00001147
# >VizWiz_train_00001148
# >VizWiz_train_00001149
# >VizWiz_train_00001150
# >VizWiz_train_00001151
# >VizWiz_train_00001152
# >VizWiz_train_00001153
# >VizWiz_train_00001154
# >VizWiz_train_00001155
# >VizWiz_train_00001157
# >VizWiz_train_00001158
# >VizWiz_train_00001159
# >VizWiz_train_00001160
# >VizWiz_train_00001161
# >VizWiz_train_00001162
# >VizWiz_train_00001163
# >VizWiz_train_00001164
# >VizWiz_train_00001165
# >VizWiz_train_00001166
# >VizWiz_train_00001167
# >VizWiz_train_00001168
# >VizWiz_train_00001169
# >VizWiz_train_00001170
# >VizWiz_train_00001171
# >VizWiz_train_00001172
# >VizWiz_train_00001173
# >VizWiz_train_00001174
# >VizWiz_train_00001175
# >VizWiz_train_00001176
# >VizWiz_train_00001177
# >VizWiz_train_00001178
# >VizWiz_train_00001179
# >VizWiz_train_00001180
# >VizWiz_train_00001181
# >VizWiz_train_00001182
# >VizWiz_train_00001183
# >VizWiz_train_00001184
# >VizWiz_train_00001185
# >VizWiz_train_00001186
# >VizWiz_train_00001187
# >VizWiz_train_00001188
# >VizWiz_train_00001189
# >VizWiz_train_00001190
# >VizWiz_train_00001191
# >VizWiz_train_00001192
# >VizWiz_train_00001193
# >VizWiz_train_00001194
# >VizWiz_train_00001195
# >VizWiz_train_00001196
# >VizWiz_train_00001197
# >VizWiz_train_00001198
# >VizWiz_train_00001199
# >VizWiz_train_00001200
# >VizWiz_train_00001201
# >VizWiz_train_00001202
# >VizWiz_train_00001203
# >VizWiz_train_00001204
# >VizWiz_train_00001205
# >VizWiz_train_00001206
# >VizWiz_train_00001207
# >VizWiz_train_00001208
# >VizWiz_train_00001209
# >VizWiz_train_00001210
# >VizWiz_train_00001211
# >VizWiz_train_00001212
# >VizWiz_train_00001213
# >VizWiz_train_00001214
# >VizWiz_train_00001215
# >VizWiz_train_00001216
# >VizWiz_train_00001218
# >VizWiz_train_00001219
# >VizWiz_train_00001220
# >VizWiz_train_00001221
# >VizWiz_train_00001222
# >VizWiz_train_00001223
# >VizWiz_train_00001225
# >VizWiz_train_00001226
# >VizWiz_train_00001227
# >VizWiz_train_00001228
# >VizWiz_train_00001229
# >VizWiz_train_00001230
# >VizWiz_train_00001231
# >VizWiz_train_00001232
# >VizWiz_train_00001233
# >VizWiz_train_00001234
# >VizWiz_train_00001235
# >VizWiz_train_00001236
# >VizWiz_train_00001237
# >VizWiz_train_00001238
# >VizWiz_train_00001239
# >VizWiz_train_00001240
# >VizWiz_train_00001241
# >VizWiz_train_00001242
# >VizWiz_train_00001243
# >VizWiz_train_00001244
# >VizWiz_train_00001245
# >VizWiz_train_00001246
# >VizWiz_train_00001247
# >VizWiz_train_00001248
# >VizWiz_train_00001249
# >VizWiz_train_00001250
# >VizWiz_train_00001251
# >VizWiz_train_00001252
# >VizWiz_train_00001253
# >VizWiz_train_00001254
# >VizWiz_train_00001255
# >VizWiz_train_00001256
# >VizWiz_train_00001257
# >VizWiz_train_00001258
# >VizWiz_train_00001259
# >VizWiz_train_00001260
# >VizWiz_train_00001261
# >VizWiz_train_00001262
# >VizWiz_train_00001263
# >VizWiz_train_00001264
# >VizWiz_train_00001265
# >VizWiz_train_00001266
# >VizWiz_train_00001267
# >VizWiz_train_00001268
# >VizWiz_train_00001269
# >VizWiz_train_00001270
# >VizWiz_train_00001271
# >VizWiz_train_00001272
# >VizWiz_train_00001273
# >VizWiz_train_00001274
# >VizWiz_train_00001275
# >VizWiz_train_00001276
# >VizWiz_train_00001277
# >VizWiz_train_00001278
# >VizWiz_train_00001279
# >VizWiz_train_00001280
# >VizWiz_train_00001281
# >VizWiz_train_00001282
# >VizWiz_train_00001283
# >VizWiz_train_00001284
# >VizWiz_train_00001285
# >VizWiz_train_00001286
# >VizWiz_train_00001287
# >VizWiz_train_00001288
# >VizWiz_train_00001289
# >VizWiz_train_00001290
# >VizWiz_train_00001291
# >VizWiz_train_00001292
# >VizWiz_train_00001293
# >VizWiz_train_00001294
# >VizWiz_train_00001295
# >VizWiz_train_00001296
# >VizWiz_train_00001297
# >VizWiz_train_00001298
# >VizWiz_train_00001299
# >VizWiz_train_00001300
# >VizWiz_train_00001301
# >VizWiz_train_00001302
# >VizWiz_train_00001303
# >VizWiz_train_00001304
# >VizWiz_train_00001305
# >VizWiz_train_00001306
# >VizWiz_train_00001307
# >VizWiz_train_00001308
# >VizWiz_train_00001309
# >VizWiz_train_00001310
# >VizWiz_train_00001311
# >VizWiz_train_00001312
# >VizWiz_train_00001313
# >VizWiz_train_00001314
# >VizWiz_train_00001315
# >VizWiz_train_00001316
# >VizWiz_train_00001317
# >VizWiz_train_00001318
# >VizWiz_train_00001319
# >VizWiz_train_00001320
# >VizWiz_train_00001321
# >VizWiz_train_00001322
# >VizWiz_train_00001323
# >VizWiz_train_00001324
# >VizWiz_train_00001325
# >VizWiz_train_00001326
# >VizWiz_train_00001327
# >VizWiz_train_00001328
# >VizWiz_train_00001329
# >VizWiz_train_00001330
# >VizWiz_train_00001331
# >VizWiz_train_00001332
# >VizWiz_train_00001333
# >VizWiz_train_00001334
# >VizWiz_train_00001335
# >VizWiz_train_00001336
# >VizWiz_train_00001337
# >VizWiz_train_00001338
# >VizWiz_train_00001339
# >VizWiz_train_00001341
# >VizWiz_train_00001342
# >VizWiz_train_00001343
# >VizWiz_train_00001344
# >VizWiz_train_00001345
# >VizWiz_train_00001346
# >VizWiz_train_00001347
# >VizWiz_train_00001348
# >VizWiz_train_00001349
# >VizWiz_train_00001350
# >VizWiz_train_00001351
# >VizWiz_train_00001352
# >VizWiz_train_00001353
# >VizWiz_train_00001354
# >VizWiz_train_00001355
# >VizWiz_train_00001356
# >VizWiz_train_00001357
# >VizWiz_train_00001358
# >VizWiz_train_00001359
# >VizWiz_train_00001360
# >VizWiz_train_00001361
# >VizWiz_train_00001362
# >VizWiz_train_00001363
# >VizWiz_train_00001364
# >VizWiz_train_00001365
# >VizWiz_train_00001366
# >VizWiz_train_00001367
# >VizWiz_train_00001368
# >VizWiz_train_00001369
# >VizWiz_train_00001370
# >VizWiz_train_00001371
# >VizWiz_train_00001372
# >VizWiz_train_00001373
# >VizWiz_train_00001374
# >VizWiz_train_00001375
# >VizWiz_train_00001376
# >VizWiz_train_00001377
# >VizWiz_train_00001378
# >VizWiz_train_00001379
# >VizWiz_train_00001380
# >VizWiz_train_00001381
# >VizWiz_train_00001382
# >VizWiz_train_00001383
# >VizWiz_train_00001384
# >VizWiz_train_00001385
# >VizWiz_train_00001386
# >VizWiz_train_00001387
# >VizWiz_train_00001388
# >VizWiz_train_00001389
# >VizWiz_train_00001390
# >VizWiz_train_00001391
# >VizWiz_train_00001392
# >VizWiz_train_00001393
# >VizWiz_train_00001394
# >VizWiz_train_00001395
# >VizWiz_train_00001396
# >VizWiz_train_00001397
# >VizWiz_train_00001398
# >VizWiz_train_00001399
# >VizWiz_train_00001400
# >VizWiz_train_00001401
# >VizWiz_train_00001402
# >VizWiz_train_00001403
# >VizWiz_train_00001404
# >VizWiz_train_00001405
# >VizWiz_train_00001406
# >VizWiz_train_00001407
# >VizWiz_train_00001408
# >VizWiz_train_00001409
# >VizWiz_train_00001410
# >VizWiz_train_00001411
# >VizWiz_train_00001412
# >VizWiz_train_00001413
# >VizWiz_train_00001414
# >VizWiz_train_00001415
# >VizWiz_train_00001416
# >VizWiz_train_00001417
# >VizWiz_train_00001418
# >VizWiz_train_00001419
# >VizWiz_train_00001420
# >VizWiz_train_00001421
# >VizWiz_train_00001422
# >VizWiz_train_00001423
# >VizWiz_train_00001425
# >VizWiz_train_00001426
# >VizWiz_train_00001427
# >VizWiz_train_00001428
# >VizWiz_train_00001429
# >VizWiz_train_00001430
# >VizWiz_train_00001431
# >VizWiz_train_00001432
# >VizWiz_train_00001433
# >VizWiz_train_00001434
# >VizWiz_train_00001435
# >VizWiz_train_00001436
# >VizWiz_train_00001437
# >VizWiz_train_00001438
# >VizWiz_train_00001439
# >VizWiz_train_00001440
# >VizWiz_train_00001441
# >VizWiz_train_00001442
# >VizWiz_train_00001443
# >VizWiz_train_00001444
# >VizWiz_train_00001445
# >VizWiz_train_00001446
# >VizWiz_train_00001447
# >VizWiz_train_00001448
# >VizWiz_train_00001449
# >VizWiz_train_00001450
# >VizWiz_train_00001451
# >VizWiz_train_00001452
# >VizWiz_train_00001453
# >VizWiz_train_00001454
# >VizWiz_train_00001455
# >VizWiz_train_00001456
# >VizWiz_train_00001457
# >VizWiz_train_00001458
# >VizWiz_train_00001459
# >VizWiz_train_00001460
# >VizWiz_train_00001461
# >VizWiz_train_00001462
# >VizWiz_train_00001463
# >VizWiz_train_00001464
# >VizWiz_train_00001465
# >VizWiz_train_00001466
# >VizWiz_train_00001467
# >VizWiz_train_00001468
# >VizWiz_train_00001469
# >VizWiz_train_00001470
# >VizWiz_train_00001471
# >VizWiz_train_00001472
# >VizWiz_train_00001473
# >VizWiz_train_00001474
# >VizWiz_train_00001475
# >VizWiz_train_00001476
# >VizWiz_train_00001477
# >VizWiz_train_00001478
# >VizWiz_train_00001479
# >VizWiz_train_00001480
# >VizWiz_train_00001481
# >VizWiz_train_00001482
# >VizWiz_train_00001483
# >VizWiz_train_00001485
# >VizWiz_train_00001486
# >VizWiz_train_00001487
# >VizWiz_train_00001488
# >VizWiz_train_00001489
# >VizWiz_train_00001490
# >VizWiz_train_00001491
# >VizWiz_train_00001492
# >VizWiz_train_00001493
# >VizWiz_train_00001494
# >VizWiz_train_00001495
# >VizWiz_train_00001496
# >VizWiz_train_00001497
# >VizWiz_train_00001498
# >VizWiz_train_00001499
# >VizWiz_train_00001500
# >VizWiz_train_00001501
# >VizWiz_train_00001502
# >VizWiz_train_00001503
# >VizWiz_train_00001504
# >VizWiz_train_00001505
# >VizWiz_train_00001506
# >VizWiz_train_00001507
# >VizWiz_train_00001508
# >VizWiz_train_00001509
# >VizWiz_train_00001510
# >VizWiz_train_00001511
# >VizWiz_train_00001512
# >VizWiz_train_00001513
# >VizWiz_train_00001514
# >VizWiz_train_00001515
# >VizWiz_train_00001516
# >VizWiz_train_00001517
# >VizWiz_train_00001518
# >VizWiz_train_00001519
# >VizWiz_train_00001520
# >VizWiz_train_00001521
# >VizWiz_train_00001522
# >VizWiz_train_00001523
# >VizWiz_train_00001524
# >VizWiz_train_00001525
# >VizWiz_train_00001526
# >VizWiz_train_00001527
# >VizWiz_train_00001528
# >VizWiz_train_00001529
# >VizWiz_train_00001530
# >VizWiz_train_00001531
# >VizWiz_train_00001532
# >VizWiz_train_00001533
# >VizWiz_train_00001534
# >VizWiz_train_00001535
# >VizWiz_train_00001536
# >VizWiz_train_00001537
# >VizWiz_train_00001538
# >VizWiz_train_00001539
# >VizWiz_train_00001540
# >VizWiz_train_00001541
# >VizWiz_train_00001542
# >VizWiz_train_00001543
# >VizWiz_train_00001544
# >VizWiz_train_00001545
# >VizWiz_train_00001546
# >VizWiz_train_00001547
# >VizWiz_train_00001548
# >VizWiz_train_00001549
# >VizWiz_train_00001550
# >VizWiz_train_00001551
# >VizWiz_train_00001552
# >VizWiz_train_00001553
# >VizWiz_train_00001554
# >VizWiz_train_00001555
# >VizWiz_train_00001557
# >VizWiz_train_00001558
# >VizWiz_train_00001559
# >VizWiz_train_00001560
# >VizWiz_train_00001561
# >VizWiz_train_00001562
# >VizWiz_train_00001563
# >VizWiz_train_00001564
# >VizWiz_train_00001566
# >VizWiz_train_00001567
# >VizWiz_train_00001568
# >VizWiz_train_00001569
# >VizWiz_train_00001570
# >VizWiz_train_00001572
# >VizWiz_train_00001573
# >VizWiz_train_00001574
# >VizWiz_train_00001575
# >VizWiz_train_00001576
# >VizWiz_train_00001577
# >VizWiz_train_00001578
# >VizWiz_train_00001579
# >VizWiz_train_00001580
# >VizWiz_train_00001581
# >VizWiz_train_00001582
# >VizWiz_train_00001583
# >VizWiz_train_00001584
# >VizWiz_train_00001585
# >VizWiz_train_00001586
# >VizWiz_train_00001587
# >VizWiz_train_00001588
# >VizWiz_train_00001589
# >VizWiz_train_00001590
# >VizWiz_train_00001591
# >VizWiz_train_00001592
# >VizWiz_train_00001593
# >VizWiz_train_00001594
# >VizWiz_train_00001595
# >VizWiz_train_00001596
# >VizWiz_train_00001597
# >VizWiz_train_00001598
# >VizWiz_train_00001599
# >VizWiz_train_00001600
# >VizWiz_train_00001601
# >VizWiz_train_00001602
# >VizWiz_train_00001603
# >VizWiz_train_00001604
# >VizWiz_train_00001605
# >VizWiz_train_00001606
# >VizWiz_train_00001607
# >VizWiz_train_00001608
# >VizWiz_train_00001609
# >VizWiz_train_00001610
# >VizWiz_train_00001611
# >VizWiz_train_00001612
# >VizWiz_train_00001613
# >VizWiz_train_00001614
# >VizWiz_train_00001615
# >VizWiz_train_00001616
# >VizWiz_train_00001617
# >VizWiz_train_00001618
# >VizWiz_train_00001619
# >VizWiz_train_00001620
# >VizWiz_train_00001621
# >VizWiz_train_00001622
# >VizWiz_train_00001623
# >VizWiz_train_00001624
# >VizWiz_train_00001625
# >VizWiz_train_00001626
# >VizWiz_train_00001627
# >VizWiz_train_00001628
# >VizWiz_train_00001629
# >VizWiz_train_00001631
# >VizWiz_train_00001632
# >VizWiz_train_00001633
# >VizWiz_train_00001634
# >VizWiz_train_00001635
# >VizWiz_train_00001636
# >VizWiz_train_00001637
# >VizWiz_train_00001638
# >VizWiz_train_00001639
# >VizWiz_train_00001640
# >VizWiz_train_00001641
# >VizWiz_train_00001642
# >VizWiz_train_00001643
# >VizWiz_train_00001644
# >VizWiz_train_00001645
# >VizWiz_train_00001646
# >VizWiz_train_00001647
# >VizWiz_train_00001648
# >VizWiz_train_00001649
# >VizWiz_train_00001650
# >VizWiz_train_00001651
# >VizWiz_train_00001652
# >VizWiz_train_00001653
# >VizWiz_train_00001654
# >VizWiz_train_00001655
# >VizWiz_train_00001656
# >VizWiz_train_00001657
# >VizWiz_train_00001658
# >VizWiz_train_00001659
# >VizWiz_train_00001660
# >VizWiz_train_00001661
# >VizWiz_train_00001662
# >VizWiz_train_00001663
# >VizWiz_train_00001664
# >VizWiz_train_00001665
# >VizWiz_train_00001666
# >VizWiz_train_00001667
# >VizWiz_train_00001668
# >VizWiz_train_00001669
# >VizWiz_train_00001670
# >VizWiz_train_00001671
# >VizWiz_train_00001672
# >VizWiz_train_00001673
# >VizWiz_train_00001674
# >VizWiz_train_00001675
# >VizWiz_train_00001676
# >VizWiz_train_00001677
# >VizWiz_train_00001679
# >VizWiz_train_00001680
# >VizWiz_train_00001681
# >VizWiz_train_00001682
# >VizWiz_train_00001683
# >VizWiz_train_00001684
# >VizWiz_train_00001685
# >VizWiz_train_00001686
# >VizWiz_train_00001687
# >VizWiz_train_00001688
# >VizWiz_train_00001689
# >VizWiz_train_00001690
# >VizWiz_train_00001691
# >VizWiz_train_00001692
# >VizWiz_train_00001693
# >VizWiz_train_00001694
# >VizWiz_train_00001695
# >VizWiz_train_00001696
# >VizWiz_train_00001697
# >VizWiz_train_00001698
# >VizWiz_train_00001699
# >VizWiz_train_00001700
# >VizWiz_train_00001701
# >VizWiz_train_00001702
# >VizWiz_train_00001703
# >VizWiz_train_00001704
# >VizWiz_train_00001705
# >VizWiz_train_00001706
# >VizWiz_train_00001707
# >VizWiz_train_00001708
# >VizWiz_train_00001709
# >VizWiz_train_00001710
# >VizWiz_train_00001711
# >VizWiz_train_00001712
# >VizWiz_train_00001713
# >VizWiz_train_00001714
# >VizWiz_train_00001715
# >VizWiz_train_00001716
# >VizWiz_train_00001717
# >VizWiz_train_00001718
# >VizWiz_train_00001719
# >VizWiz_train_00001720
# >VizWiz_train_00001721
# >VizWiz_train_00001722
# >VizWiz_train_00001723
# >VizWiz_train_00001724
# >VizWiz_train_00001725
# >VizWiz_train_00001726
# >VizWiz_train_00001727
# >VizWiz_train_00001728
# >VizWiz_train_00001729
# >VizWiz_train_00001730
# >VizWiz_train_00001731
# >VizWiz_train_00001732
# >VizWiz_train_00001733
# >VizWiz_train_00001734
# >VizWiz_train_00001735
# >VizWiz_train_00001736
# >VizWiz_train_00001737
# >VizWiz_train_00001738
# >VizWiz_train_00001739
# >VizWiz_train_00001740
# >VizWiz_train_00001741
# >VizWiz_train_00001742
# >VizWiz_train_00001743
# >VizWiz_train_00001744
# >VizWiz_train_00001745
# >VizWiz_train_00001746
# >VizWiz_train_00001747
# >VizWiz_train_00001748
# >VizWiz_train_00001749
# >VizWiz_train_00001750
# >VizWiz_train_00001751
# >VizWiz_train_00001752
# >VizWiz_train_00001753
# >VizWiz_train_00001754
# >VizWiz_train_00001755
# >VizWiz_train_00001756
# >VizWiz_train_00001757
# >VizWiz_train_00001758
# >VizWiz_train_00001759
# >VizWiz_train_00001760
# >VizWiz_train_00001761
# >VizWiz_train_00001762
# >VizWiz_train_00001763
# >VizWiz_train_00001764
# >VizWiz_train_00001765
# >VizWiz_train_00001766
# >VizWiz_train_00001767
# >VizWiz_train_00001768
# >VizWiz_train_00001769
# >VizWiz_train_00001770
# >VizWiz_train_00001771
# >VizWiz_train_00001772
# >VizWiz_train_00001773
# >VizWiz_train_00001774
# >VizWiz_train_00001775
# >VizWiz_train_00001776
# >VizWiz_train_00001777
# >VizWiz_train_00001778
# >VizWiz_train_00001779
# >VizWiz_train_00001780
# >VizWiz_train_00001781
# >VizWiz_train_00001782
# >VizWiz_train_00001783
# >VizWiz_train_00001784
# >VizWiz_train_00001785
# >VizWiz_train_00001786
# >VizWiz_train_00001787
# >VizWiz_train_00001788
# >VizWiz_train_00001789
# >VizWiz_train_00001790
# >VizWiz_train_00001791
# >VizWiz_train_00001792
# >VizWiz_train_00001793
# >VizWiz_train_00001794
# >VizWiz_train_00001795
# >VizWiz_train_00001796
# >VizWiz_train_00001797
# >VizWiz_train_00001798
# >VizWiz_train_00001799
# >VizWiz_train_00001800
# >VizWiz_train_00001801
# >VizWiz_train_00001802
# >VizWiz_train_00001803
# >VizWiz_train_00001805
# >VizWiz_train_00001806
# >VizWiz_train_00001807
# >VizWiz_train_00001808
# >VizWiz_train_00001809
# >VizWiz_train_00001810
# >VizWiz_train_00001811
# >VizWiz_train_00001812
# >VizWiz_train_00001813
# >VizWiz_train_00001814
# >VizWiz_train_00001815
# >VizWiz_train_00001816
# >VizWiz_train_00001817
# >VizWiz_train_00001818
# >VizWiz_train_00001819
# >VizWiz_train_00001820
# >VizWiz_train_00001821
# >VizWiz_train_00001822
# >VizWiz_train_00001823
# >VizWiz_train_00001824
# >VizWiz_train_00001825
# >VizWiz_train_00001826
# >VizWiz_train_00001827
# >VizWiz_train_00001828
# >VizWiz_train_00001829
# >VizWiz_train_00001830
# >VizWiz_train_00001831
# >VizWiz_train_00001832
# >VizWiz_train_00001833
# >VizWiz_train_00001834
# >VizWiz_train_00001835
# >VizWiz_train_00001836
# >VizWiz_train_00001837
# >VizWiz_train_00001838
# >VizWiz_train_00001839
# >VizWiz_train_00001840
# >VizWiz_train_00001841
# >VizWiz_train_00001842
# >VizWiz_train_00001843
# >VizWiz_train_00001844
# >VizWiz_train_00001845
# >VizWiz_train_00001846
# >VizWiz_train_00001847
# >VizWiz_train_00001848
# >VizWiz_train_00001849
# >VizWiz_train_00001850
# >VizWiz_train_00001851
# >VizWiz_train_00001852
# >VizWiz_train_00001853
# >VizWiz_train_00001854
# >VizWiz_train_00001855
# >VizWiz_train_00001856
# >VizWiz_train_00001857
# >VizWiz_train_00001858
# >VizWiz_train_00001859
# >VizWiz_train_00001860
# >VizWiz_train_00001861
# >VizWiz_train_00001862
# >VizWiz_train_00001863
# >VizWiz_train_00001864
# >VizWiz_train_00001865
# >VizWiz_train_00001866
# >VizWiz_train_00001867
# >VizWiz_train_00001868
# >VizWiz_train_00001869
# >VizWiz_train_00001870
# >VizWiz_train_00001871
# >VizWiz_train_00001872
# >VizWiz_train_00001873
# >VizWiz_train_00001874
# >VizWiz_train_00001875
# >VizWiz_train_00001876
# >VizWiz_train_00001877
# >VizWiz_train_00001878
# >VizWiz_train_00001879
# >VizWiz_train_00001880
# >VizWiz_train_00001881
# >VizWiz_train_00001882
# >VizWiz_train_00001883
# >VizWiz_train_00001885
# >VizWiz_train_00001886
# >VizWiz_train_00001887
# >VizWiz_train_00001888
# >VizWiz_train_00001889
# >VizWiz_train_00001890
# >VizWiz_train_00001891
# >VizWiz_train_00001892
# >VizWiz_train_00001893
# >VizWiz_train_00001894
# >VizWiz_train_00001895
# >VizWiz_train_00001896
# >VizWiz_train_00001897
# >VizWiz_train_00001898
# >VizWiz_train_00001899
# >VizWiz_train_00001900
# >VizWiz_train_00001901
# >VizWiz_train_00001902
# >VizWiz_train_00001903
# >VizWiz_train_00001904
# >VizWiz_train_00001905
# >VizWiz_train_00001906
# >VizWiz_train_00001907
# >VizWiz_train_00001908
# >VizWiz_train_00001909
# >VizWiz_train_00001910
# >VizWiz_train_00001911
# >VizWiz_train_00001912
# >VizWiz_train_00001913
# >VizWiz_train_00001914
# >VizWiz_train_00001915
# >VizWiz_train_00001916
# >VizWiz_train_00001917
# >VizWiz_train_00001918
# >VizWiz_train_00001919
# >VizWiz_train_00001920
# >VizWiz_train_00001921
# >VizWiz_train_00001922
# >VizWiz_train_00001923
# >VizWiz_train_00001924
# >VizWiz_train_00001925
# >VizWiz_train_00001926
# >VizWiz_train_00001927
# >VizWiz_train_00001928
# >VizWiz_train_00001929
# >VizWiz_train_00001930
# >VizWiz_train_00001931
# >VizWiz_train_00001932
# >VizWiz_train_00001933
# >VizWiz_train_00001934
# >VizWiz_train_00001935
# >VizWiz_train_00001936
# >VizWiz_train_00001937
# >VizWiz_train_00001938
# >VizWiz_train_00001939
# >VizWiz_train_00001940
# >VizWiz_train_00001941
# >VizWiz_train_00001942
# >VizWiz_train_00001943
# >VizWiz_train_00001944
# >VizWiz_train_00001945
# >VizWiz_train_00001946
# >VizWiz_train_00001947
# >VizWiz_train_00001948
# >VizWiz_train_00001949
# >VizWiz_train_00001950
# >VizWiz_train_00001951
# >VizWiz_train_00001952
# >VizWiz_train_00001953
# >VizWiz_train_00001954
# >VizWiz_train_00001955
# >VizWiz_train_00001956
# >VizWiz_train_00001957
# >VizWiz_train_00001958
# >VizWiz_train_00001959
# >VizWiz_train_00001960
# >VizWiz_train_00001961
# >VizWiz_train_00001962
# >VizWiz_train_00001963
# ...
# >VizWiz_val_00006990
# >VizWiz_val_00006991
# >VizWiz_val_00006992
# >VizWiz_val_00006993
# >VizWiz_val_00006994
# >VizWiz_val_00006995
# >VizWiz_val_00006996
# >VizWiz_val_00006997
# >VizWiz_val_00006998
# >VizWiz_val_00006999
# >VizWiz_val_00007000
# >VizWiz_val_00007001
# >VizWiz_val_00007002
# >VizWiz_val_00007003
# >VizWiz_val_00007004
# >VizWiz_val_00007005
# >VizWiz_val_00007006
# >VizWiz_val_00007007
# >VizWiz_val_00007008
# >VizWiz_val_00007009
# >VizWiz_val_00007010
# >VizWiz_val_00007011
# >VizWiz_val_00007012
# >VizWiz_val_00007013
# >VizWiz_val_00007014
# >VizWiz_val_00007015
# >VizWiz_val_00007016
# >VizWiz_val_00007017
# >VizWiz_val_00007018
# >VizWiz_val_00007019
# >VizWiz_val_00007020
# >VizWiz_val_00007021
# >VizWiz_val_00007022
# >VizWiz_val_00007023
# >VizWiz_val_00007024
# >VizWiz_val_00007025
# >VizWiz_val_00007026
# >VizWiz_val_00007027
# >VizWiz_val_00007028
# >VizWiz_val_00007029
# >VizWiz_val_00007030
# >VizWiz_val_00007031
# >VizWiz_val_00007032
# >VizWiz_val_00007033
# >VizWiz_val_00007034
# >VizWiz_val_00007035
# >VizWiz_val_00007036
# >VizWiz_val_00007037
# >VizWiz_val_00007038
# >VizWiz_val_00007039
# >VizWiz_val_00007040
# >VizWiz_val_00007041
# >VizWiz_val_00007042
# >VizWiz_val_00007043
# >VizWiz_val_00007044
# >VizWiz_val_00007045
# >VizWiz_val_00007046
# >VizWiz_val_00007047
# >VizWiz_val_00007048
# >VizWiz_val_00007049
# >VizWiz_val_00007050
# >VizWiz_val_00007051
# >VizWiz_val_00007052
# >VizWiz_val_00007053
# >VizWiz_val_00007054
# >VizWiz_val_00007055
# >VizWiz_val_00007056
# >VizWiz_val_00007057
# >VizWiz_val_00007058
# >VizWiz_val_00007059
# >VizWiz_val_00007060
# >VizWiz_val_00007061
# >VizWiz_val_00007062
# >VizWiz_val_00007063
# >VizWiz_val_00007064
# >VizWiz_val_00007065
# >VizWiz_val_00007066
# >VizWiz_val_00007067
# >VizWiz_val_00007068
# >VizWiz_val_00007069
# >VizWiz_val_00007070
# >VizWiz_val_00007071
# >VizWiz_val_00007072
# >VizWiz_val_00007073
# >VizWiz_val_00007074
# >VizWiz_val_00007075
# >VizWiz_val_00007076
# >VizWiz_val_00007077
# >VizWiz_val_00007078
# >VizWiz_val_00007079
# >VizWiz_val_00007080
# >VizWiz_val_00007081
# >VizWiz_val_00007082
# >VizWiz_val_00007083
# >VizWiz_val_00007084
# >VizWiz_val_00007085
# >VizWiz_val_00007086
# >VizWiz_val_00007087
# >VizWiz_val_00007088
# >VizWiz_val_00007089
# >VizWiz_val_00007090
# >VizWiz_val_00007091
# >VizWiz_val_00007092
# >VizWiz_val_00007093
# >VizWiz_val_00007094
# >VizWiz_val_00007095
# >VizWiz_val_00007096
# >VizWiz_val_00007097
# >VizWiz_val_00007098
# >VizWiz_val_00007099
# >VizWiz_val_00007100
# >VizWiz_val_00007101
# >VizWiz_val_00007102
# >VizWiz_val_00007103
# >VizWiz_val_00007104
# >VizWiz_val_00007105
# >VizWiz_val_00007106
# >VizWiz_val_00007107
# >VizWiz_val_00007108
# >VizWiz_val_00007109
# >VizWiz_val_00007110
# >VizWiz_val_00007111
# >VizWiz_val_00007112
# >VizWiz_val_00007113
# >VizWiz_val_00007114
# >VizWiz_val_00007115
# >VizWiz_val_00007116
# >VizWiz_val_00007117
# >VizWiz_val_00007118
# >VizWiz_val_00007119
# >VizWiz_val_00007120
# >VizWiz_val_00007121
# >VizWiz_val_00007122
# >VizWiz_val_00007123
# >VizWiz_val_00007124
# >VizWiz_val_00007125
# >VizWiz_val_00007126
# >VizWiz_val_00007127
# >VizWiz_val_00007128
# >VizWiz_val_00007129
# >VizWiz_val_00007130
# >VizWiz_val_00007131
# >VizWiz_val_00007132
# >VizWiz_val_00007133
# >VizWiz_val_00007134
# >VizWiz_val_00007135
# >VizWiz_val_00007136
# >VizWiz_val_00007137
# >VizWiz_val_00007138
# >VizWiz_val_00007139
# >VizWiz_val_00007140
# >VizWiz_val_00007141
# >VizWiz_val_00007142
# >VizWiz_val_00007143
# >VizWiz_val_00007144
# >VizWiz_val_00007145
# >VizWiz_val_00007146
# >VizWiz_val_00007147
# >VizWiz_val_00007148
# >VizWiz_val_00007149
# >VizWiz_val_00007150
# >VizWiz_val_00007151
# >VizWiz_val_00007152
# >VizWiz_val_00007153
# >VizWiz_val_00007154
# >VizWiz_val_00007155
# >VizWiz_val_00007156
# >VizWiz_val_00007157
# >VizWiz_val_00007158
# >VizWiz_val_00007159
# >VizWiz_val_00007160
# >VizWiz_val_00007161
# >VizWiz_val_00007162
# >VizWiz_val_00007163
# >VizWiz_val_00007164
# >VizWiz_val_00007165
# >VizWiz_val_00007166
# >VizWiz_val_00007167
# >VizWiz_val_00007168
# >VizWiz_val_00007169
# >VizWiz_val_00007170
# >VizWiz_val_00007171
# >VizWiz_val_00007172
# >VizWiz_val_00007173
# >VizWiz_val_00007174
# >VizWiz_val_00007175
# >VizWiz_val_00007176
# >VizWiz_val_00007177
# >VizWiz_val_00007178
# >VizWiz_val_00007179
# >VizWiz_val_00007180
# >VizWiz_val_00007181
# >VizWiz_val_00007182
# >VizWiz_val_00007183
# >VizWiz_val_00007184
# >VizWiz_val_00007185
# >VizWiz_val_00007186
# >VizWiz_val_00007187
# >VizWiz_val_00007188
# >VizWiz_val_00007189
# >VizWiz_val_00007190
# >VizWiz_val_00007191
# >VizWiz_val_00007192
# >VizWiz_val_00007193
# >VizWiz_val_00007194
# >VizWiz_val_00007195
# >VizWiz_val_00007196
# >VizWiz_val_00007197
# >VizWiz_val_00007198
# >VizWiz_val_00007199
# >VizWiz_val_00007200
# >VizWiz_val_00007201
# >VizWiz_val_00007202
# >VizWiz_val_00007203
# >VizWiz_val_00007204
# >VizWiz_val_00007205
# >VizWiz_val_00007206
# >VizWiz_val_00007207
# >VizWiz_val_00007208
# >VizWiz_val_00007209
# >VizWiz_val_00007210
# >VizWiz_val_00007211
# >VizWiz_val_00007212
# >VizWiz_val_00007213
# >VizWiz_val_00007214
# >VizWiz_val_00007215
# >VizWiz_val_00007216
# >VizWiz_val_00007217
# >VizWiz_val_00007218
# >VizWiz_val_00007219
# >VizWiz_val_00007220
# >VizWiz_val_00007221
# >VizWiz_val_00007222
# >VizWiz_val_00007223
# >VizWiz_val_00007224
# >VizWiz_val_00007225
# >VizWiz_val_00007226
# >VizWiz_val_00007227
# >VizWiz_val_00007228
# >VizWiz_val_00007229
# >VizWiz_val_00007230
# >VizWiz_val_00007231
# >VizWiz_val_00007232
# >VizWiz_val_00007233
# >VizWiz_val_00007234
# >VizWiz_val_00007235
# >VizWiz_val_00007236
# >VizWiz_val_00007237
# >VizWiz_val_00007238
# >VizWiz_val_00007239
# >VizWiz_val_00007240
# >VizWiz_val_00007241
# >VizWiz_val_00007242
# >VizWiz_val_00007243
# >VizWiz_val_00007244
# >VizWiz_val_00007245
# >VizWiz_val_00007246
# >VizWiz_val_00007247
# >VizWiz_val_00007248
# >VizWiz_val_00007249
# >VizWiz_val_00007250
# >VizWiz_val_00007251
# >VizWiz_val_00007252
# >VizWiz_val_00007253
# >VizWiz_val_00007254
# >VizWiz_val_00007255
# >VizWiz_val_00007256
# >VizWiz_val_00007257
# >VizWiz_val_00007258
# >VizWiz_val_00007259
# >VizWiz_val_00007260
# >VizWiz_val_00007261
# >VizWiz_val_00007262
# >VizWiz_val_00007263
# >VizWiz_val_00007264
# >VizWiz_val_00007265
# >VizWiz_val_00007266
# >VizWiz_val_00007267
# >VizWiz_val_00007268
# >VizWiz_val_00007269
# >VizWiz_val_00007270
# >VizWiz_val_00007271
# >VizWiz_val_00007272
# >VizWiz_val_00007273
# >VizWiz_val_00007274
# >VizWiz_val_00007275
# >VizWiz_val_00007276
# >VizWiz_val_00007277
# >VizWiz_val_00007278
# >VizWiz_val_00007279
# >VizWiz_val_00007280
# >VizWiz_val_00007281
# >VizWiz_val_00007282
# >VizWiz_val_00007283
# >VizWiz_val_00007284
# >VizWiz_val_00007285
# >VizWiz_val_00007286
# >VizWiz_val_00007287
# >VizWiz_val_00007288
# >VizWiz_val_00007289
# >VizWiz_val_00007290
# >VizWiz_val_00007291
# >VizWiz_val_00007292
# >VizWiz_val_00007293
# >VizWiz_val_00007294
# >VizWiz_val_00007295
# >VizWiz_val_00007296
# >VizWiz_val_00007297
# >VizWiz_val_00007298
# >VizWiz_val_00007299
# >VizWiz_val_00007300
# >VizWiz_val_00007301
# >VizWiz_val_00007302
# >VizWiz_val_00007303
# >VizWiz_val_00007304
# >VizWiz_val_00007305
# >VizWiz_val_00007306
# >VizWiz_val_00007307
# >VizWiz_val_00007308
# >VizWiz_val_00007309
# >VizWiz_val_00007310
# >VizWiz_val_00007311
# >VizWiz_val_00007312
# >VizWiz_val_00007313
# >VizWiz_val_00007314
# >VizWiz_val_00007315
# >VizWiz_val_00007316
# >VizWiz_val_00007317
# >VizWiz_val_00007318
# >VizWiz_val_00007319
# >VizWiz_val_00007320
# >VizWiz_val_00007321
# >VizWiz_val_00007322
# >VizWiz_val_00007323
# >VizWiz_val_00007324
# >VizWiz_val_00007325
# >VizWiz_val_00007326
# >VizWiz_val_00007327
# >VizWiz_val_00007328
# >VizWiz_val_00007329
# >VizWiz_val_00007330
# >VizWiz_val_00007331
# >VizWiz_val_00007332
# >VizWiz_val_00007333
# >VizWiz_val_00007334
# >VizWiz_val_00007335
# >VizWiz_val_00007336
# >VizWiz_val_00007337
# >VizWiz_val_00007338
# >VizWiz_val_00007339
# >VizWiz_val_00007340
# >VizWiz_val_00007341
# >VizWiz_val_00007342
# >VizWiz_val_00007343
# >VizWiz_val_00007344
# >VizWiz_val_00007345
# >VizWiz_val_00007346
# >VizWiz_val_00007347
# >VizWiz_val_00007348
# >VizWiz_val_00007349
# >VizWiz_val_00007350
# >VizWiz_val_00007351
# >VizWiz_val_00007352
# >VizWiz_val_00007353
# >VizWiz_val_00007354
# >VizWiz_val_00007355
# >VizWiz_val_00007356
# >VizWiz_val_00007357
# >VizWiz_val_00007358
# >VizWiz_val_00007359
# >VizWiz_val_00007360
# >VizWiz_val_00007361
# >VizWiz_val_00007362
# >VizWiz_val_00007363
# >VizWiz_val_00007364
# >VizWiz_val_00007365
# >VizWiz_val_00007366
# >VizWiz_val_00007367
# >VizWiz_val_00007368
# >VizWiz_val_00007369
# >VizWiz_val_00007370
# >VizWiz_val_00007371
# >VizWiz_val_00007372
# >VizWiz_val_00007373
# >VizWiz_val_00007374
# >VizWiz_val_00007375
# >VizWiz_val_00007376
# >VizWiz_val_00007377
# >VizWiz_val_00007378
# >VizWiz_val_00007379
# >VizWiz_val_00007380
# >VizWiz_val_00007381
# >VizWiz_val_00007382
# >VizWiz_val_00007383
# >VizWiz_val_00007384
# >VizWiz_val_00007385
# >VizWiz_val_00007386
# >VizWiz_val_00007387
# >VizWiz_val_00007388
# >VizWiz_val_00007389
# >VizWiz_val_00007390
# >VizWiz_val_00007391
# >VizWiz_val_00007392
# >VizWiz_val_00007393
# >VizWiz_val_00007394
# >VizWiz_val_00007395
# >VizWiz_val_00007396
# >VizWiz_val_00007397
# >VizWiz_val_00007398
# >VizWiz_val_00007399
# >VizWiz_val_00007400
# >VizWiz_val_00007401
# >VizWiz_val_00007402
# >VizWiz_val_00007403
# >VizWiz_val_00007404
# >VizWiz_val_00007405
# >VizWiz_val_00007406
# >VizWiz_val_00007407
# >VizWiz_val_00007408
# >VizWiz_val_00007409
# >VizWiz_val_00007410
# >VizWiz_val_00007411
# >VizWiz_val_00007412
# >VizWiz_val_00007413
# >VizWiz_val_00007414
# >VizWiz_val_00007415
# >VizWiz_val_00007416
# >VizWiz_val_00007417
# >VizWiz_val_00007418
# >VizWiz_val_00007419
# >VizWiz_val_00007420
# >VizWiz_val_00007421
# >VizWiz_val_00007422
# >VizWiz_val_00007423
# >VizWiz_val_00007424
# >VizWiz_val_00007425
# >VizWiz_val_00007426
# >VizWiz_val_00007427
# >VizWiz_val_00007428
# >VizWiz_val_00007429
# >VizWiz_val_00007430
# >VizWiz_val_00007431
# >VizWiz_val_00007432
# >VizWiz_val_00007433
# >VizWiz_val_00007434
# >VizWiz_val_00007435
# >VizWiz_val_00007436
# >VizWiz_val_00007437
# >VizWiz_val_00007438
# >VizWiz_val_00007439
# >VizWiz_val_00007440
# >VizWiz_val_00007441
# >VizWiz_val_00007442
# >VizWiz_val_00007443
# >VizWiz_val_00007444
# >VizWiz_val_00007445
# >VizWiz_val_00007446
# >VizWiz_val_00007447
# >VizWiz_val_00007448
# >VizWiz_val_00007449
# >VizWiz_val_00007450
# >VizWiz_val_00007451
# >VizWiz_val_00007452
# >VizWiz_val_00007453
# >VizWiz_val_00007454
# >VizWiz_val_00007455
# >VizWiz_val_00007456
# >VizWiz_val_00007457
# >VizWiz_val_00007458
# >VizWiz_val_00007459
# >VizWiz_val_00007460
# >VizWiz_val_00007461
# >VizWiz_val_00007462
# >VizWiz_val_00007463
# >VizWiz_val_00007464
# >VizWiz_val_00007465
# >VizWiz_val_00007466
# >VizWiz_val_00007467
# >VizWiz_val_00007468
# >VizWiz_val_00007469
# >VizWiz_val_00007470
# >VizWiz_val_00007471
# >VizWiz_val_00007472
# >VizWiz_val_00007473
# >VizWiz_val_00007474
# >VizWiz_val_00007475
# >VizWiz_val_00007476
# >VizWiz_val_00007477
# >VizWiz_val_00007478
# >VizWiz_val_00007479
# >VizWiz_val_00007480
# >VizWiz_val_00007481
# >VizWiz_val_00007482
# >VizWiz_val_00007483
# >VizWiz_val_00007484
# >VizWiz_val_00007485
# >VizWiz_val_00007486
# >VizWiz_val_00007487
# >VizWiz_val_00007488
# >VizWiz_val_00007489
# >VizWiz_val_00007490
# >VizWiz_val_00007491
# >VizWiz_val_00007492
# >VizWiz_val_00007493
# >VizWiz_val_00007494
# >VizWiz_val_00007495
# >VizWiz_val_00007496
# >VizWiz_val_00007497
# >VizWiz_val_00007498
# >VizWiz_val_00007499
# >VizWiz_val_00007500
# >VizWiz_val_00007501
# >VizWiz_val_00007502
# >VizWiz_val_00007503
# >VizWiz_val_00007504
# >VizWiz_val_00007505
# >VizWiz_val_00007506
# >VizWiz_val_00007507
# >VizWiz_val_00007508
# >VizWiz_val_00007509
# >VizWiz_val_00007510
# >VizWiz_val_00007511
# >VizWiz_val_00007512
# >VizWiz_val_00007513
# >VizWiz_val_00007514
# >VizWiz_val_00007515
# >VizWiz_val_00007516
# >VizWiz_val_00007517
# >VizWiz_val_00007518
# >VizWiz_val_00007519
# >VizWiz_val_00007520
# >VizWiz_val_00007521
# >VizWiz_val_00007522
# >VizWiz_val_00007523
# >VizWiz_val_00007524
# >VizWiz_val_00007525
# >VizWiz_val_00007526
# >VizWiz_val_00007527
# >VizWiz_val_00007528
# >VizWiz_val_00007529
# >VizWiz_val_00007530
# >VizWiz_val_00007531
# >VizWiz_val_00007532
# >VizWiz_val_00007533
# >VizWiz_val_00007534
# >VizWiz_val_00007535
# >VizWiz_val_00007536
# >VizWiz_val_00007537
# >VizWiz_val_00007538
# >VizWiz_val_00007539
# >VizWiz_val_00007540
# >VizWiz_val_00007541
# >VizWiz_val_00007542
# >VizWiz_val_00007543
# >VizWiz_val_00007544
# >VizWiz_val_00007545
# >VizWiz_val_00007546
# >VizWiz_val_00007547
# >VizWiz_val_00007548
# >VizWiz_val_00007549
# >VizWiz_val_00007550
# >VizWiz_val_00007551
# >VizWiz_val_00007552
# >VizWiz_val_00007553
# >VizWiz_val_00007554
# >VizWiz_val_00007555
# >VizWiz_val_00007556
# >VizWiz_val_00007557
# >VizWiz_val_00007558
# >VizWiz_val_00007559
# >VizWiz_val_00007560
# >VizWiz_val_00007561
# >VizWiz_val_00007562
# >VizWiz_val_00007563
# >VizWiz_val_00007564
# >VizWiz_val_00007565
# >VizWiz_val_00007566
# >VizWiz_val_00007567
# >VizWiz_val_00007568
# >VizWiz_val_00007569
# >VizWiz_val_00007570
# >VizWiz_val_00007571
# >VizWiz_val_00007572
# >VizWiz_val_00007573
# >VizWiz_val_00007574
# >VizWiz_val_00007575
# >VizWiz_val_00007576
# >VizWiz_val_00007577
# >VizWiz_val_00007578
# >VizWiz_val_00007579
# >VizWiz_val_00007580
# >VizWiz_val_00007581
# >VizWiz_val_00007582
# >VizWiz_val_00007583
# >VizWiz_val_00007584
# >VizWiz_val_00007585
# >VizWiz_val_00007586
# >VizWiz_val_00007587
# >VizWiz_val_00007588
# >VizWiz_val_00007589
# >VizWiz_val_00007590
# >VizWiz_val_00007591
# >VizWiz_val_00007592
# >VizWiz_val_00007593
# >VizWiz_val_00007594
# >VizWiz_val_00007595
# >VizWiz_val_00007596
# >VizWiz_val_00007597
# >VizWiz_val_00007598
# >VizWiz_val_00007599
# >VizWiz_val_00007600
# >VizWiz_val_00007601
# >VizWiz_val_00007602
# >VizWiz_val_00007603
# >VizWiz_val_00007604
# >VizWiz_val_00007605
# >VizWiz_val_00007606
# >VizWiz_val_00007607
# >VizWiz_val_00007608
# >VizWiz_val_00007609
# >VizWiz_val_00007610
# >VizWiz_val_00007611
# >VizWiz_val_00007612
# >VizWiz_val_00007613
# >VizWiz_val_00007614
# >VizWiz_val_00007615
# >VizWiz_val_00007616
# >VizWiz_val_00007617
# >VizWiz_val_00007618
# >VizWiz_val_00007619
# >VizWiz_val_00007620
# >VizWiz_val_00007621
# >VizWiz_val_00007622
# >VizWiz_val_00007623
# >VizWiz_val_00007624
# >VizWiz_val_00007625
# >VizWiz_val_00007626
# >VizWiz_val_00007627
# >VizWiz_val_00007628
# >VizWiz_val_00007629
# >VizWiz_val_00007630
# >VizWiz_val_00007631
# >VizWiz_val_00007632
# >VizWiz_val_00007633
# >VizWiz_val_00007634
# >VizWiz_val_00007635
# >VizWiz_val_00007636
# >VizWiz_val_00007637
# >VizWiz_val_00007638
# >VizWiz_val_00007639
# >VizWiz_val_00007640
# >VizWiz_val_00007641
# >VizWiz_val_00007642
# >VizWiz_val_00007643
# >VizWiz_val_00007644
# >VizWiz_val_00007645
# >VizWiz_val_00007646
# >VizWiz_val_00007647
# >VizWiz_val_00007648
# >VizWiz_val_00007649
# >VizWiz_val_00007650
# >VizWiz_val_00007651
# >VizWiz_val_00007652
# >VizWiz_val_00007653
# >VizWiz_val_00007654
# >VizWiz_val_00007655
# >VizWiz_val_00007656
# >VizWiz_val_00007657
# >VizWiz_val_00007658
# >VizWiz_val_00007659
# >VizWiz_val_00007660
# >VizWiz_val_00007661
# >VizWiz_val_00007662
# >VizWiz_val_00007663
# >VizWiz_val_00007664
# >VizWiz_val_00007665
# >VizWiz_val_00007666
# >VizWiz_val_00007667
# >VizWiz_val_00007668
# >VizWiz_val_00007669
# >VizWiz_val_00007670
# >VizWiz_val_00007671
# >VizWiz_val_00007672
# >VizWiz_val_00007673
# >VizWiz_val_00007674
# >VizWiz_val_00007675
# >VizWiz_val_00007676
# >VizWiz_val_00007677
# >VizWiz_val_00007678
# >VizWiz_val_00007679
# >VizWiz_val_00007680
# >VizWiz_val_00007681
# >VizWiz_val_00007682
# >VizWiz_val_00007683
# >VizWiz_val_00007684
# >VizWiz_val_00007685
# >VizWiz_val_00007686
# >VizWiz_val_00007687
# >VizWiz_val_00007688
# >VizWiz_val_00007689
# >VizWiz_val_00007690
# >VizWiz_val_00007691
# >VizWiz_val_00007692
# >VizWiz_val_00007693
# >VizWiz_val_00007694
# >VizWiz_val_00007695
# >VizWiz_val_00007696
# >VizWiz_val_00007697
# >VizWiz_val_00007698
# >VizWiz_val_00007699
# >VizWiz_val_00007700
# >VizWiz_val_00007701
# >VizWiz_val_00007702
# >VizWiz_val_00007703
# >VizWiz_val_00007704
# >VizWiz_val_00007705
# >VizWiz_val_00007706
# >VizWiz_val_00007707
# >VizWiz_val_00007708
# >VizWiz_val_00007709
# >VizWiz_val_00007710
# >VizWiz_val_00007711
# >VizWiz_val_00007712
# >VizWiz_val_00007713
# >VizWiz_val_00007714
# >VizWiz_val_00007715
# >VizWiz_val_00007716
# >VizWiz_val_00007717
# >VizWiz_val_00007718
# >VizWiz_val_00007719
# >VizWiz_val_00007720
# >VizWiz_val_00007721
# >VizWiz_val_00007722
# >VizWiz_val_00007723
# >VizWiz_val_00007724
# >VizWiz_val_00007725
# >VizWiz_val_00007726
# >VizWiz_val_00007727
# >VizWiz_val_00007728
# >VizWiz_val_00007729
# >VizWiz_val_00007730
# >VizWiz_val_00007731
# >VizWiz_val_00007732
# >VizWiz_val_00007733
# >VizWiz_val_00007734
# >VizWiz_val_00007735
# >VizWiz_val_00007736
# >VizWiz_val_00007737
# >VizWiz_val_00007738
# >VizWiz_val_00007739
# >VizWiz_val_00007740
# >VizWiz_val_00007741
# >VizWiz_val_00007742
# >VizWiz_val_00007743
# >VizWiz_val_00007744
# >VizWiz_val_00007745
# >VizWiz_val_00007746
# >VizWiz_val_00007747
# >VizWiz_val_00007748
# >VizWiz_val_00007749
# Extracted Features: 30650

# %%
from numpy import array
from pickle import load
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import Add
from keras.callbacks import ModelCheckpoint
import keras
import numpy as np

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# load photo features
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo, vocab_size):
	X1, X2, y = list(), list(), list()
	# walk through each description for the image
	for desc in desc_list:
		# encode the sequence
		seq = tokenizer.texts_to_sequences([desc])[0]
		# split one sequence into multiple X,y pairs
		for i in range(1, len(seq)):
			# split into input and output pair
			in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence
			in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence
			out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
			X1.append(photo)
			X2.append(in_seq)
			y.append(out_seq)
	return array(X1), array(X2), array(y)

# define the captioning model
def define_model(vocab_size, max_length):
	# feature extractor model
	inputs1 = Input(shape=(1000,))
	fe1 = Dropout(0.5)(inputs1)
	fe2 = Dense(256, activation='relu')(fe1)
	# sequence model
	inputs2 = Input(shape=(max_length,))
	se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
	se2 = Dropout(0.5)(se1)
	se3 = LSTM(256)(se2)
	# decoder model
	decoder1 = Add()([fe2, se3])
	decoder2 = Dense(256, activation='relu')(decoder1)
	outputs = Dense(vocab_size, activation='softmax')(decoder2)
	# tie it together [image, seq] [word]
	model = Model(inputs=[inputs1, inputs2], outputs=outputs)
	# compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam')
	# summarize model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

def data_generator(descriptions, photos, tokenizer, max_length, vocab_size):
    # loop for ever over images
    while 1:
        for key, desc_list in descriptions.items():
            # retrieve the photo feature
            photo = photos[key][0]
            in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo, vocab_size)
            yield [[in_img, in_seq], out_word]

# data generator, intended to be used in a call to model.fit_generator()
def data_generator1(descriptions, photos, tokenizer, max_length, vocab_size, photos_per_batch):            
    X1, X2, y = list(), list(), list()
    n=0
    while 1:
        for key, desc_list in descriptions.items():
            if key in photos.keys():
                photo = photos[key][0]
                n+=1
                for desc in desc_list:
                    seq = tokenizer.texts_to_sequences([desc])[0]
                    for i in range(1, len(seq)):
                        in_seq, out_seq = seq[:i], seq[i]
                        in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                        out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                        X1.append(photo)
                        X2.append(in_seq)
                        y.append(out_seq)

            if n==photos_per_batch:
                X11=np.reshape(array(X1),(array(X1).shape[0],1000))
                yield [[X11, array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

filename = 'training_images_names'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# define the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
epochs = 6
steps = len(train_descriptions)
photos_per_batch = 0
for i in range(epochs):
    # create the data generator
    if i<2:
        keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
        photos_per_batch = 6
    elif i<4:
        keras.optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
        photos_per_batch = 12
    else:
        keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
        photos_per_batch = 24
    generator = data_generator1(train_descriptions, train_features, tokenizer, max_length, vocab_size, photos_per_batch)
    # fit for one epoch
    steps = len(train_descriptions)//photos_per_batch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1, initial_epoch=0)
    # save model
    model.save('model_' + str(i) + '.h5')
# Out:
# Dataset: 22900
# Descriptions: train=22900
# Photos: train=22900
# Vocabulary Size: 18006
# Description Length: 105
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_31 (InputLayer)       [(None, 105)]                0         []
#
#  input_30 (InputLayer)       [(None, 1000)]               0         []
#
#  embedding_11 (Embedding)    (None, 105, 256)             4609536   ['input_31[0][0]']
#
#  dropout_22 (Dropout)        (None, 1000)                 0         ['input_30[0][0]']
#
#  dropout_23 (Dropout)        (None, 105, 256)             0         ['embedding_11[0][0]']
#
#  dense_31 (Dense)            (None, 256)                  256256    ['dropout_22[0][0]']
#
#  lstm_11 (LSTM)              (None, 256)                  525312    ['dropout_23[0][0]']
#
#  add_10 (Add)                (None, 256)                  0         ['dense_31[0][0]',
#                                                                      'lstm_11[0][0]']
#
#  dense_32 (Dense)            (None, 256)                  65792     ['add_10[0][0]']
#
#  dense_33 (Dense)            (None, 18006)                4627542   ['dense_32[0][0]']
#
# ==================================================================================================
# Total params: 10084438 (38.47 MB)
# Trainable params: 10084438 (38.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 3816/3816 [==============================] - 2422s 634ms/step - loss: 4.9566
# /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 3816/3816 [==============================] - 2534s 664ms/step - loss: 4.1478
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 1908/1908 [==============================] - 2181s 1s/step - loss: 3.8601
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 1908/1908 [==============================] - 2715s 1s/step - loss: 3.7097
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 954/954 [==============================] - 2289s 2s/step - loss: 3.5821
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# 954/954 [==============================] - 2200s 2s/step - loss: 3.5056

# %%
pip install nltk pydot
# Out:
# Requirement already satisfied: nltk in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (3.8.1)
# Collecting pydot
#   Downloading pydot-2.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: click in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: tqdm in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: joblib in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from nltk) (2023.12.25)
# Requirement already satisfied: pyparsing>=3 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from pydot) (3.1.1)
# Installing collected packages: pydot
# Successfully installed pydot-2.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from numpy import array
from pickle import load
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import Add
from keras.callbacks import ModelCheckpoint
import keras
import numpy as np

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# load photo features
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo, vocab_size):
	X1, X2, y = list(), list(), list()
	# walk through each description for the image
	for desc in desc_list:
		# encode the sequence
		seq = tokenizer.texts_to_sequences([desc])[0]
		# split one sequence into multiple X,y pairs
		for i in range(1, len(seq)):
			# split into input and output pair
			in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence
			in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence
			out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
			X1.append(photo)
			X2.append(in_seq)
			y.append(out_seq)
	return array(X1), array(X2), array(y)

# define the captioning model
def define_model(vocab_size, max_length):
	# feature extractor model
	inputs1 = Input(shape=(1000,))
	fe1 = Dropout(0.5)(inputs1)
	fe2 = Dense(256, activation='relu')(fe1)
	# sequence model
	inputs2 = Input(shape=(max_length,))
	se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
	se2 = Dropout(0.5)(se1)
	se3 = LSTM(256)(se2)
	# decoder model
	decoder1 = Add()([fe2, se3])
	decoder2 = Dense(256, activation='relu')(decoder1)
	outputs = Dense(vocab_size, activation='softmax')(decoder2)
	# tie it together [image, seq] [word]
	model = Model(inputs=[inputs1, inputs2], outputs=outputs)
	# compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam')
	# summarize model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

def data_generator(descriptions, photos, tokenizer, max_length, vocab_size):
    # loop for ever over images
    while 1:
        for key, desc_list in descriptions.items():
            # retrieve the photo feature
            photo = photos[key][0]
            in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo, vocab_size)
            yield [[in_img, in_seq], out_word]

# data generator, intended to be used in a call to model.fit_generator()
def data_generator1(descriptions, photos, tokenizer, max_length, vocab_size, photos_per_batch):            
    X1, X2, y = list(), list(), list()
    n=0
    while 1:
        for key, desc_list in descriptions.items():
            if key in photos.keys():
                photo = photos[key][0]
                n+=1
                for desc in desc_list:
                    seq = tokenizer.texts_to_sequences([desc])[0]
                    for i in range(1, len(seq)):
                        in_seq, out_seq = seq[:i], seq[i]
                        in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                        out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                        X1.append(photo)
                        X2.append(in_seq)
                        y.append(out_seq)

            if n==photos_per_batch:
                X11=np.reshape(array(X1),(array(X1).shape[0],1000))
                yield [[X11, array(X2)], array(y)]
                X1, X2, y = list(), list(), list()
                n=0

filename = 'training_images_names'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# define the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
# epochs = 6
# steps = len(train_descriptions)
# photos_per_batch = 0
# for i in range(epochs):
#     # create the data generator
#     if i<2:
#         keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
#         photos_per_batch = 6
#     elif i<4:
#         keras.optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
#         photos_per_batch = 12
#     else:
#         keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
#         photos_per_batch = 24
#     generator = data_generator1(train_descriptions, train_features, tokenizer, max_length, vocab_size, photos_per_batch)
#     # fit for one epoch
#     steps = len(train_descriptions)//photos_per_batch
#     model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1, initial_epoch=0)
#     # save model
#     model.save('model_' + str(i) + '.h5')
# Out:
# Dataset: 22900
# Descriptions: train=22900
# Photos: train=22900
# Vocabulary Size: 18006
# Description Length: 105
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 105)]                0         []
#
#  input_1 (InputLayer)        [(None, 1000)]               0         []
#
#  embedding (Embedding)       (None, 105, 256)             4609536   ['input_2[0][0]']
#
#  dropout (Dropout)           (None, 1000)                 0         ['input_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 105, 256)             0         ['embedding[0][0]']
#
#  dense (Dense)               (None, 256)                  256256    ['dropout[0][0]']
#
#  lstm (LSTM)                 (None, 256)                  525312    ['dropout_1[0][0]']
#
#  add (Add)                   (None, 256)                  0         ['dense[0][0]',
#                                                                      'lstm[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  65792     ['add[0][0]']
#
#  dense_2 (Dense)             (None, 18006)                4627542   ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 10084438 (38.47 MB)
# Trainable params: 10084438 (38.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
pip install pycocoevalcap
# Out:
# Collecting pycocoevalcap
#   Downloading pycocoevalcap-1.2-py3-none-any.whl (104.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 12.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting pycocotools>=2.0.2
#   Downloading pycocotools-2.0.7-cp39-cp39-macosx_10_9_universal2.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from pycocotools>=2.0.2->pycocoevalcap) (1.26.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from pycocotools>=2.0.2->pycocoevalcap) (3.8.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (6.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (23.2)
# Requirement already satisfied: pillow>=8 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (10.2.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.1.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (3.17.0)
# Requirement already satisfied: six>=1.5 in /Users/danianmercado/.pyenv/versions/3.9.18/envs/jupyter_env_machine/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap) (1.16.0)
# Installing collected packages: pycocotools, pycocoevalcap
# Successfully installed pycocoevalcap-1.2 pycocotools-2.0.7
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from numpy import argmax
from pickle import load
import nltk
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.meteor_score import meteor_score
from nltk.translate.gleu_score import corpus_gleu

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# load photo features
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# evaluate the skill of the model
def evaluate_model(model, descriptions, photos, tokenizer, max_length):
    actual, predicted = list(), list()
    actual_dict, predicted_dict = dict(), dict()
    # step over the whole set
    for key, desc_list in descriptions.items():
        # generate description
        yhat = generate_desc(model, tokenizer, photos[key], max_length)
        # store actual and predicted
        references = [d.split() for d in desc_list]
        actual.append(references)
        predicted.append(yhat.split())

    # calculate BLEU score
    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
    
    # calculate METEOR score
    meteor_scores = [meteor_score(ref, hyp) for ref, hyp in zip(actual, predicted)]
    print('METEOR: %f' % (sum(meteor_scores) / len(meteor_scores)))
    # calculate spice score
    gleu_scores = [corpus_gleu(ref[0], hyp) for ref, hyp in zip(actual, predicted)]
    print('GLEU: %f' % (sum(gleu_scores) / len(gleu_scores)))
	

# prepare tokenizer on train set

# load training dataset (6K)
filename = 'training_images_names'
nltk.download('wordnet')
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# prepare test set

# load test set
filename = 'val_images_names'
test = load_set(filename)
print('Dataset: %d' % len(test))
# descriptions
test_descriptions = load_clean_descriptions('descriptions.txt', test)
print('Descriptions: test=%d' % len(test_descriptions))
# photo features
test_features = load_photo_features('features.pkl', test)
print('Photos: test=%d' % len(test_features))

# load the model
filename = 'model_5.h5'
model = load_model(filename)
# evaluate model
evaluate_model(model, test_descriptions, test_features, tokenizer, max_length)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/danianmercado/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Dataset: 22900
# Descriptions: train=22900
# Vocabulary Size: 18006
# Description Length: 105
# Dataset: 254
# Descriptions: test=254
# Photos: test=254
# BLEU-1: 0.490419
# BLEU-2: 0.236733
# BLEU-3: 0.159127
# BLEU-4: 0.069524
# METEOR: 0.273912
# GLEU: 0.000000

# %%
from keras.preprocessing.text import Tokenizer
from pickle import dump

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# load training dataset (6K)
filename = 'training_images_names'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
# save the tokenizer
dump(tokenizer, open('tokenizer.pkl', 'wb'))
# Out:
# Dataset: 22900
# Descriptions: train=22900

# %%
train_img_set
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train_img_set
#
# NameError: name 'train_img_set' is not defined

# %%
from pickle import load
from numpy import argmax
from keras.preprocessing.sequence import pad_sequences
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.models import Model
from keras.models import load_model
import os
from os import listdir
import matplotlib.pyplot as plt


# extract features from each photo in the directory
def extract_features(filename):
	# load the model
	model = VGG16()
	# re-structure the model
	model.layers.pop()
	model = Model(inputs=model.inputs, outputs=model.layers[-1].output)
	# load the photo
	image = load_img(filename, target_size=(224, 224))
	# convert the image pixels to a numpy array
	image = img_to_array(image)
	# reshape data for the model
	image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
	# prepare the image for the VGG model
	image = preprocess_input(image)
	# get features
	feature = model.predict(image, verbose=0)
	return feature

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate a description for an image
def generate_desc(model, tokenizer, photo, max_length):
	# seed the generation process
	in_text = 'startseq'
	# iterate over the whole length of the sequence
	for i in range(max_length):
		# integer encode input sequence
		sequence = tokenizer.texts_to_sequences([in_text])[0]
		# pad input
		sequence = pad_sequences([sequence], maxlen=max_length)
		# predict next word
		yhat = model.predict([photo,sequence], verbose=0)
		# convert probability to integer
		yhat = argmax(yhat)
		# map integer to word
		word = word_for_id(yhat, tokenizer)
		# stop if we cannot map the word
		if word is None:
			break
		# append as input for generating the next word
		in_text += ' ' + word
		# stop if we predict the end of the sequence
		if word == 'endseq':
			break
	return in_text

# load the tokenizer
tokenizer = load(open('tokenizer.pkl', 'rb'))
# pre-define the max sequence length (from training)
max_length = 105
# load the model
model = load_model('model_5.h5')
# load and prepare the photograph
path = os.path.abspath('.') + '/data/val/VizWiz_val_00004698.jpg'
plt.imshow(plt.imread(path))
photo = extract_features(path)
# generate description
description = generate_desc(model, tokenizer, photo, max_length)
print(description)
# Out:
# startseq box of frozen food with the nutrition facts facing up endseq
